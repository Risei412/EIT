# %% [markdown]
# # Notes on the NV-EIT project
# Since July 2nd, 2024

# %% [markdown]
# # Abstract
#
# Electromagnetically indueced transparency of the NV system allows all-optical magnetometry. Previously demonstrated work on NV-EIT required either the near-GSLAC condition or the strain-induced excited state mixing for the construction of lambda-type system. The application to magnetometry is still limited because the EIT signal is expected to decrease under strong magnetic field or increasing temperature. In this project, we exploit the ESLAC feature to extend the operating conditions of the NV-EIT. From numerical calculation, we examine (i) the ESLAC feature under vaious strain and temperature conditions, (ii) the robustness of the EIT signal agains perturbations of magnetic field and strain, and (iii) at which temperature the EIT signal dissappears. The simulation predicts a more robust EIT lambda system under a magnetic field of ~1250 G. Experimental results (Work in progress...)

# %% [markdown]
# # Introduction
#
# This chapter introduces the basic concept of EIT and the brief history of the EIT realization focused mainly on the NV system.

# %% [markdown]
# ## Electromagnetically induced Transparency
#
# Electromagnetically induced transparency (EIT) is a quantum interference effect that permits the propagation of light through an otherwise opaque atomic medium. The coherent optical nonlinearity renders a medium transparent within a narrow spectral range around an absorption line. Extreme dispersion is also created within this transparency "window" which leads to "slow light."
#
# > Electromagnetically induced transparency (EIT) is an optical coherence effect which provides exquisite control over the absorption and dispersion in atomic media. In atoms with two coherent ground-state levels that can be optically excited to the same excited state (a “ 𝛬 system”), EIT results in ultranarrow transmissive spectral features, with resonance quality factors exceeding 10^12 and more than 10^7 reduction in optical group velocity. Numerous EIT-based applications are being pursued, including precision measurement, few-photon nonlinear optics, optical buffers, and quantum optical memories. --Wikipedia
#
#
# EIT has been observed in atomic systems. The most notable platforms are rare-earth-doped systems. However, one drawback of these systems is weak optical transitions. As an alternative systemm, a solid-state approach is desirable for compatibility with large-scale fabrication processes.

# %% [markdown]
# ## NV-EIT at low temperature
#
# EIT is also osbesrved in NV system. The first demonstration in 2001 by Hemmer et al. used the GSLAC to mix the $m_s = 0$ and $m_s = -1$. Then the other groups started to realize NV-EIT using the strong strain coupling in the excited states.

# %% [markdown]
# ### [Hemmer 2001]
#
# **NV-EIT was first observed with the use of a high-defect-density diamond and the necessity of a large magnetic field ( ∼0.1  T) limited the range of possible applications.**
#
# https://lapt.ece.northwestern.edu/files/2002-000.pdf
#
#
# Abstract
# > Raman-excited spin coherences were experimentally observed in nitrogen-vacancy (N-V) diamond color centers by means of nondegenerate four-wave mixing and electromagnetically induced transparency. The maximal
# absorption suppression was found to be 17%, which corresponds to 70% of what is possible given the random geometric orientation of the N-V center in diamond. In the context of quantum computing in solids, this level of transparency represents efficient preparation of quantum bits, as well as the ability to perform arbitrary single-quantum-bit rotat
#
# Experimental conditions
# - NV density = 30 ppm, optical density of 0.6 at 1 W/cm$^2$ at 15 K
# - Bias field = 1050 G, $m_s= 0 $ and $m_s = -1$ are split by 120 MHz, making a partial mixing of the ground states
# - Lasers R1 and R2 act as Raman pump beams toproduce a coherent population trapping
# - Laser P is a probe beam that is diffraceted from a phase grating produced by the two-photon coherence and generates a diffracted beam D.
#
#  $$ k_D = k_{R2} - k_{R1} + k_P $$
#
# - EIT signal contrast of 17%, which corresponds to 70% of what is possible (i.e., 25%) given the rando geometric orientation of the N-V cente
#
# <div style="max-width:400px;margin-left: auto; margin-right: auto;">
# <img src=images\Hemmer_2001jpg.jpg witdh="100">
# </div>
# <center>Figure: Figures from Hemmer 2001</center>

# %% [markdown]
# ### [Santori 2006]
#
# **NV-EIT was observed with high defect density under near zero-field. The EIT signal was highly dependent on strain.**
#
# Abstract
# > Coherent population trapping at zero magnetic field was observed for nitrogen-vacancy centers in diamond under optical excitation. This was measured as a reduction in photoluminescence when the detuning between two excitation lasers matched the 2.88 GHz crystal-field splitting of the color center ground states. This behavior is highly sensitive to strain, which modifies the excited states, and was unexpected following recent experiments demonstrating optical readout of single nitrogen-vacancy electron spins based on cycling transitions. These results demonstrate for the first time that three-level Lambda configurations suitable for proposed quantum information applications can be realized simultaneously for all four orientations of nitrogen-vacancy centers at zero magnetic field.
#
#
# <div style="max-width:500px;margin-left: auto; margin-right: auto;">
# <img src=images\santori_2006_tranparence.jpg witdh="100">
# </div>
# <center>Figure: Figures from Santori 2006</center>

# %% [markdown]
# ### [Santori 2006b]
#
# **NV-EIT was observed under zero-field. The EIT signal was highly dependent on strain.**
#
# Abstract
# > Coherent population trapping is demonstrated in single nitrogen-vacancy centers in diamond under optical excitation. For sufficient excitation power, the fluorescence intensity drops almost to the background level when the laser modulation frequency matches the 2.88 GHz splitting of the ground states. The results are well described theoretically by a four-level model, allowing the relative transition strengths to be determined for individual centers. The results show that all-optical control of single spins is possible in diamond.
#
#
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=images\santori_2006b.jpg witdh="100">
# </div>
# <center>Figure: Figures from Santori 2006b</center>

# %% [markdown]
# ### [Tamarat 2008]

# %% [markdown]
# ### [Togan 2011]
# https://www.nature.com/articles/nature09256#:~:text=Quantum%20entanglement%20is%20among%20the%20most%20fascinating
#
#
# **Zero-field, zero-strain EIT between $m_s = \pm 1$**

# %% [markdown]
# ### [Acosta 2013]
#
# **Strain-induced NV-EIT with low defect density under zero-magnetic field for all optical electrometry and magnetometry**
#
# Abstract
# > We use electromagnetically induced transparency (EIT) to probe the narrow electron-spin resonance of nitrogen-vacancy centers in diamond. Working with a multipass diamond chip at temperatures 6–30 K, the zero-phonon absorption line (637 nm) exhibits an optical depth of 6 and inhomogeneous linewidth of ∼30  GHz FWHM. Simultaneous optical excitation at two frequencies separated by the ground-state zero-field splitting (2.88 GHz) reveals EIT resonances with a contrast exceeding 6% and FWHM down to 0.4 MHz. The resonances provide an all-optical probe of external electric and magnetic fields with a projected photon-shot-noise-limited sensitivity of 0.2  V/cm/√Hz and 0.1  nT/√Hz, respectively. Operation of a prototype diamond-EIT magnetometer measures a noise floor of ≲1  nT/√Hz for frequencies above 10 Hz and Allan deviation of 1.3±1.1  nT for 100 s intervals. The results demonstrate the potential of diamond-EIT devices for applications ranging from quantum-optical memory to precision measurement and tests of fundamental physics.
#
#
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=images\Togan_2011.jpg witdh="100">
# </div>
# <center>Figure: Figures from Togan 2011</center>

# %% [markdown]
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=images\Acosta_2013_Lambda_configulation.jpg witdh="100">
# </div>
# <center>Figure: Figures from Acosta 2013</center>

# %% [markdown]
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=images\Acosta_2013_transmission.jpg witdh="100">
# </div>
# <center>Figure: Figures from Acosta 2013</center>

# %% [markdown]
# ## NV-EIT under higher temperature
#
# So far, NV-EIT has NOT been observed at temperature above ~50 K, primarily due to increasing phonon mixing. To realize NV-EIT at higher temperature, it is important to introduce stronger coherent coupling of either the ground stats or the excited states.

# %% [markdown]
# ## NV-EIT under strong magnetic field
#
# So far, NV-EIT has NOT been observed above 1 T of magnetic field. The reason is provided by Victor Accosta in an email exchanged with Dima.
#
# > Hi Dima,
# Gosh I haven't thought about that in a decade! Assuming what I said was even correct, I guess I was probably thinking that at high B field, spin-orbit coupling is a small perturbation and thus the optical transitions would be largely spin conserving. Which maybe doesn't completely prevent EIT but may mean that one of the two laser fields would need to be very strong, or maybe there is a more subtle issue when taking a strain-ensemble average (just guessing, honestly don't recal

# %% [markdown]
# ## NV photoluminescence
#
# Since 2000s, many people have studied the NV photolumminescence under vaious temperature and magnetic field conditions. However, until recently, the NV photoluminescence especially at mid-temperature range (50K ~ 100 K) was not understood. The Maletinski group has developed a theoretical model that explains it.

# %% [markdown]
# ### [Happacher 2023]
#
# **NV photolumiscence as a function of magnetic field and temperature is investigated systematically**
#
# Abstract
# > We present a comprehensive study of the temperature- and magnetic-field-dependent photoluminescence (PL) of individual NV centers in diamond, spanning the temperature-range from cryogenic to ambient conditions. We directly observe the emergence of the NV’s room-temperature effective excited-state structure and provide a clear explanation for a previously poorly understood broad quenching of NV PL at intermediate temperatures around 50 K, as well as the subsequent revival of NV PL. We develop a model based on two-phonon orbital averaging that quantitatively explains all of our findings, including the strong impact that strain has on the temperature dependence of the NV’s PL. These results complete our understanding of orbital averaging in the NV excited state and have significant implications for the fundamental understanding of the NV center and its applications in quantum sensing.
#
#
# <div style="max-width:500px;margin-left: auto; margin-right: auto;">
# <img src=images\Happcher_2023_a.jpg witdh="100">
# </div>
# <center>Figure: Figures from Happacher 2023</center>
#
#
# <div style="max-width:700px;margin-left: auto; margin-right: auto;">
# <img src=images\Happecher_PL_itensity.jpg witdh="100">
# </div>
# <center>Figure: Figures from Happacher 2023</center>

# %% [markdown]
# # Research question and Hypothesis

# %% [markdown]
# The central research question of this project is **"How can one increase the operating temperature of the diamond EIT using the ESLAC?"** To answer it, we break the question into three sub-questions.
#
# - **Sub issue 1: How does the lambda system of the ESLAC-induced NV-EIT differ from the strain-induced NV-EIT?**
#
# - **Sub issue 2: How robust is the ESLAC-induced EIT against perturbations of $B$ and $\delta$?**
#
# - **Sub issue 3: At which temperature does the ESLAC induced NV-EIT break down**

# %% [markdown]
# ## Sub issue 1: How does the lambda system of the ESLAC-induced NV-EIT differ from the strain-induced NV-EIT?
#
# According to [Acosta 2013], the labmda system for the strain-induced NV-EIT consists of the $^3 A_2$ graound-state $m_s = 0$ and $m_s = +1$ and the excited states whose spin is mixed due to spin-orbit coupling. The past work only looked at the strain dependence of this coupling. This coupling also depends strongly on the applied magnetic field. Thus, we first calculate the ESLAC feature under various strain conditions by simply diagonalizing the Hamiltonian. We also try to find a sweet spot in the strain and magnetic field space, where two spin quantum numbers are mixed equally in an eigenstate. This is because we speculate that equal mixing of two spin numbers leads to higher EIT signal contrast.

# %% [markdown]
# ### Hamiltonian definiton
#
# Our initial goal is to understand the Hamiltonian of the system that we consider. It is well surmarized in the review work of [Doherty 2013].

# %% [markdown]
# #### The ground states
#
# The ground-state bare Hamiltonian is
#
# $$ \hat{H}_{gs} = D_{gs} \left[\hat{S}_z^2 - \frac{S(S+1)}{3}\right] + A_{gs}^{\parallel} \hat{S}_z \hat{I}_z + A_{gs}^{\perp}\left[\hat{S}_x\hat{I}_x+\hat{S}_y\hat{I}_y\right] + P_{gs}\left[\hat{I}_z^2 - \frac{I(I+1)}{3}\right],$$
#
#     基底準位のハミルトニアンに関しては、核スピンの相互作用はいったん無視する(簡略化のため)
#
#
# where $D_{gs} = 2.87$ GHz is the zero-field splitting, $\hat{\vec{S}}= [\hat{S_x}, \hat{S_y}, \hat{S_z}]$ and $\hat{\vec{I}}= [\hat{I_x}, \hat{I_y}, \hat{I_z}]$ are the electronic and nuclear spin operators of $S = 1$ and $I=1$, respectively,\\ $A_{gs}^{\parallel}$ and $A_{gs}^{\perp}$ are the parallel and perpendicular components of the hyperfine tensor, and $P_{gs}$ is the quadrupolar coupling constant. Under the presence of a magnetic field $\vec{B} = [B_x, B_y, B_z]$, an electroc field $\vec{E} = [E_x, E_y, E_z]$, and a strain $\vec{\delta} = [\delta_x, \delta_y, \delta_z]$, the interaction Hamiltonian is
#
#
#
# \begin{align}
# \hat{V}_{gs} &= \mu_B g_{gs}^{\parallel} \hat{S}_z B_z + \mu_B g_{gs}^{\perp} \left(\hat{S}_x B_x + \hat{S}_y B_y \right)
# +\mu_Ng_N \hat{\vec{I}}\cdot \hat{\vec{S}} \\ \notag
# &+ d_{gs}^{\parallel} (E_z+ \delta_z) \left[\hat{S_z}^2 - \frac{S(S+1)}{3} \right] + d_{gs}^{\perp} (E_x+ \delta_x) \left(\hat{S}_y^2 - \hat{S}_x^2 \right)+ d_{gs}^{\perp} (E_y+ \delta_y) \left(\hat{S}_x\hat{S}_y - \hat{S}_y\hat{S}_x \right),
# \end{align}
#
#
# where $\mu_B$ is the Bohr magneton, $\mu_N$ is the nuclear magneton, $g_{gs}^{\parallel}$ and $g_{gs}^{\perp}$ are the components of the ground state electronic g-factor tensor, $g_N$ is the isotropic nuclear g-factor of 14N or 15N as required, and $d_{gs}^{\parallel}$ and $d_{gs}^{\perp}$ are the components of the ground state electric dipole moment.
#
# $$

# %% [markdown]
# ・strainが電場と同列に扱われていることについて
#
#     結晶中の歪みの単位は[m]なので、電場と同列には扱えないはず。考えられるのは
#     ダイヤモンド結晶を弾性体としてときにその内部を伝わる波、もしくはstrainによる格子振動など。
#
#
#
# 原子核の四重極子は、原子核の電荷とその形状、すなわち電荷分布
# で定まる。
# 四重極子は、原子核の形状が球状でなくなくことで生じる。
# つまり、核スピンと原子核の形状には何らかの関係性がある
# (I<1では存在しない why )
#
# http://www.hyperphysics.phy-astr.gsu.edu/hbase/Nuclear/elequad.html#:~:text=The%20nuclear%20electric%20quadrupole%20moment%20is%20a%20parameter,shape%20of%20the%20ellipsoid%20of%20nuclear%20charge%20distribution.

# %% [markdown]
# ### Numerical calculation of excited state energy levels
#
# Our next task is to calculate the excited states as a function of magnetic field and strain by diagonalizing the total Hamiltonian. Their energy levels are obtained as the eigenvalues.

# %% [markdown]
# #### Program to diagonalize the Hamiltonian

# %% [markdown]
# To carry out this task, we use the qutip package. If qutip is not installed, or if you use the Google colab to run, please execute the following code block.

# %%
# Execute this command if qutip is not installed in your python environment
# !pip install qutip
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Then we numerically defien the excited state Hamiltonian using the expression and coefficients introduced in the previous section.

# %%
import qutip as qt
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
import math
from scipy.optimize import linear_sum_assignment
from qutip import expect

#plt.rcParams['text.usetex'] = True
#rfont = {'fontname':'Times New Roman'}
matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# Spin matrix
S0 = qt.qeye(3)                                                # {1, 0, -1}
Sx, Sy, Sz = qt.jmat(1)                                        # {1, 0, -1}
sigma0 = qt.qeye(2)                                            # {Ex, Ey}
sigmax, sigmay, sigmaz = qt.sigmax(), qt.sigmay(), qt.sigmaz() # {Ex, Ey}

# Physics constant
h             = 6.626e-34        # J/Hz (planck constant)
muB           = 9.274e-24 / h    # Hz/T (Bohr magneton)

D_gs = 2.88e9 #Hz (Zero-split constant)

g_gs_para = 2.0028 # no unit #  [Doherty 2013], by Loubser , 2,0029 [Felton]  (electronic g-factor)
g_gs_perp = 2.0028 # no unit #  [Doherty 2013], by Loubser , 2,0029 [Felton]  (electronic g-factor)

d_gs_para = 17e-2 # Hz/(V/m) # [Doherty 2013], by van Oort (the ground state electrical dipole　moment)
d_gs_perp = 0.35e-2 # Hz/(V/m) # [Doherty 2013], by van Oort (the ground state electrical dipole　moment)



# 以下 Excited_stateのハミルトニアンに用いる定数
Des_para      = 1.42e9           # Hz       # [Doherty 2013], 1.44e9[Bassett 2014] 
Des_perp      = 1.55e9/2         # Hz       # [Doherty 2013], 1.541e9[Bassett 2014] 
lambdaes_para = 5.3e9            # Hz       # [Doherty 2013], 5.33e9[Bassett 2014]
lambdaes_perp = 0.2e9/np.sqrt(2) # Hz       # [Doherty 2013]
des_para      = 6e3              # Hz/(V/m) # [Doherty 2013]?
des_perp      = 6e3              # Hz/(V/m) # [Doherty 2013]?
les_para      = 0.1              # 1        # [Doherty 2013], 0.05[Bassett 2014] at 1.5K
ges_para      = 2.01             # 1        # [Doherty 2013], 2.15[Bassett 2014]
ges_perp      = 2.01             # 1        # [Doherty 2013]

# %%
#print(Sy**2 - Sx**2)
#print(Sx * Sy + Sy * Sx)

print((Sy**2-Sx**2) +(Sx*Sy-Sy*Sx))
# Out:
# Quantum object: dims=[[3], [3]], shape=(3, 3), type='oper', dtype=CSR, isherm=False
# Qobj data =
# [[ 0.+1.j  0.+0.j -1.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j]
#  [-1.+0.j  0.+0.j  0.-1.j]]

# %% [markdown]
# The bare Hamiltonian and interaction Hamiltonian parts are numerically defined as follows.

# %% [markdown]
# ESLACでは、核スピンを考慮していない場合のハミルトニアンで解析を行った。
# GSLACの場合も、同様に核スピンを考慮せず、問題をシンプル化して解析を行う。
# (核スピンを考慮すると、9×9行列となり、エネルギー準位は9つとなる。-hyper fine structure-)

# %%
# bare Hamiltonian
H_gs = D_gs * (Sz**2 - 2/3 * S0)
      

# Interaction Hamiltonian
def V_gs(E, B, delta):
    return muB * g_gs_para * Sz * B[2] \
           + muB * g_gs_perp * (Sx * B[0] + Sy * B[1])\
           + d_gs_para * (E[2] + delta[2]) * (Sz**2 - 2/3 * S0) \
           + d_gs_perp * (E[0] + delta[0]) * (Sy**2 - Sx**2) \
           + d_gs_perp  * (E[1]+delta[1]) * (Sx*Sy + Sy*Sx)

# %%
# plot energy levels
E = [0, 0, 0] # V/m
B = [0, 0, 0] # T
delta = [0/d_gs_perp/np.sqrt(2), 0/d_gs_perp/np.sqrt(2), 0] # Hz

H_tot = H_gs + V_gs(E, B, delta)
qt.plot_energy_levels([H_tot], h_labels=None, energy_levels=None, N=0, fig=None, ax=None) #qutip 5.0
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3)) #qutip 4.0



plt.show()

# %% [markdown]
# (B,strain) = (0,0)の場合の計算結果
#
# Doherty 2013の論文の図と一致している
#
# <div style="max-width:500px;margin-left: auto; margin-right: auto;">
# <img src=images\Doherty_GS_levels.jpg witdh="100">
# </div>
# <center>Figure: Figures from Doherty 2013</center>

# %%
# Out:
# 2.88

# %% [markdown]
# To obtain the energy levels under arbitrary electromagnetic fields and strain, one can use the qutip function "plot_energy_levels," which diagonalizes the Hamiltonian and creates a plot of the energy levels quickly.

# %%
# plot energy levels
E = [0, 0, 0] # V/m
B = [0, 0, 0] # T
delta = [0.75e10/d_gs_perp/np.sqrt(2), 0.75e10/d_gs_perp/np.sqrt(2), 0] # Hz

H_tot = H_gs + V_gs(E, B, delta)
qt.plot_energy_levels([H_tot], h_labels=None, energy_levels=None, N=0, fig=None, ax=None) #qutip 5.0
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3)) #qutip 4.0


plt.show()

# %% [markdown]
# off-axisのstarinをかけると
#
# $m_s = +1$ の準位は上に上がり、$m_s = 0,-1$ はともに下がる。

# %% [markdown]
# #### Dependence of excited state energy on $\vec{B}$ and $\vec{\delta}$
#
# Using the program defined in the previous section, we check how the excited state levels change as a function of magnetic field and strain.

# %% [markdown]
# ##### Dependence on off-axis strain $\delta_{\perp} \equiv \sqrt{\delta_x^2 + \delta_y^2}$
#
# We check how the excited state energy levels change according to the strain. By varing $d_{es}^{\perp} \delta_\perp$, we can reproduce the energy level diagram in [Doherty 2013][Maze 2011]. It's claer that the $|E_y⟩(0)$ and $|E_2⟩(+1)$ has a similar energy level near $d_{es}^{\perp} \delta_\perp = 8$ GHz point. The results calculated with the following code agree well with [Doherty 2013].

# %%
# strain list
deltax = deltay = np.linspace(0, 20e9) / np.sqrt(2) / d_gs_perp 

# eigenvalues
ee_strain = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, 0], delta=[deltaxi, deltayi, 0])).eigenenergies() for deltaxi, deltayi in zip(deltax, deltay)]


# plot
for i in range(3):
    plt.plot(d_gs_perp * np.sqrt(deltax**2 + deltay**2)/1e9, [eei[i]/1e9 for eei in ee_strain]) #eei[i]を 1e9で割ってGHZに換算
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp \mathrm{(GHz)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
plt.show()

# %% [markdown]
# green: $|m_s = +1>$
# orenge: $|m_s = -1>$
# blue: $|m_s = 0>$

# %%
# === delta_perp スキャン定義 ===
delta_range = np.linspace(0, 20e9)  # Hz
deltax = deltay = delta_range / np.sqrt(2) / d_gs_perp
xvals = d_gs_perp * np.sqrt(deltax**2 + deltay**2) / 1e9  # GHz for plotting

# === 基準固有状態の取得（delta = 0）===
H0 = H_gs + V_gs(E=[0,0,0], B=[0,0,0], delta=[0, 0, 0])
eval0, evec0 = H0.eigenstates()
reference_states = evec0  # 長さ3の状態リスト

# === エネルギーリスト（ラベル固定）===
energies = [[], [], []]  # 固定ラベル：index = 0,1,2

for deltaxi, deltayi in zip(deltax, deltay):
    H = H_gs + V_gs(E=[0,0,0], B=[0,0,0], delta=[deltaxi, deltayi, 0])
    evals, evecs = H.eigenstates()

    # 各状態とのオーバーラップを評価し、参照と最も近い状態を割当て
    overlaps = np.array([
        [abs(evec.overlap(ref)) for ref in reference_states]
        for evec in evecs
    ])
    #matched_indices = np.argmax(overlaps, axis=1)  # (3,) 配列：evec[i]が参照のどれと近いか
    # 負のオーバーラップをコスト関数として最適な割当（行=ref, 列=evec）
    row_ind, col_ind = linear_sum_assignment(-overlaps)
    # # index固定（matched_indices[i]=j → evec[i]はref[j]に対応）
    # for true_label in range(3):
    #     i = np.argmax(overlaps[true_label])  # ref[true_label]に最も近い evecs[i]
    #     energies[true_label].append(evals[i])
    # 割り当てられたものだけを使ってエネルギー格納
    for true_label, i in zip(row_ind, col_ind):
        energies[true_label].append(evals[i])

# === プロット ===
colors = ['tab:blue', 'tab:orange', 'tab:green']
labels = [r"$m_s = -1$", r"$m_s = 0$", r"$m_s = +1$"]

plt.figure(figsize=(7,5))
for i in range(3):
    plt.plot(xvals, np.array(energies[i])/1e9, label=labels[i], color=colors[i])
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp$ (GHz)")
plt.ylabel(r"Energy $E$ (GHz)")
plt.title("Energy levels vs transverse strain (label-tracked)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 次に、$\delta$ と $\delta_x$ との成す角度 $\theta$ との依存性を調べてみる。
#
# $\delta_x = \delta \cos \theta$
#
# $\delta_y = \delta \sin \theta$

# %% [markdown]
# $\theta = 0$ の場合として計算してみる。

# %%
# strain list
deltax =  np.linspace(0, 5e9) / d_gs_perp 


# eigenvalues
ee_strain = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, 0], delta=[deltaxi, 0, 0])).eigenenergies() for deltaxi  in deltax]


print(len(ee_strain))

# plot
for i in range(3):
    plt.plot(d_gs_perp * np.sqrt(deltax**2)/1e9, [eei[i]/1e9 for eei in ee_strain]) #eei[i]を 1e9で割ってGHZに換算
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp \mathrm{(GHz)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
plt.show()
# Out:
# 50

# %%
# === delta_perp スキャン定義 ===
delta_range = np.linspace(0, 20e9)  # Hz
deltax = delta_range / d_gs_perp
xvals = d_gs_perp * np.sqrt(deltax**2) / 1e9  # GHz for plotting

# === 基準固有状態の取得（delta = 0）===
H0 = H_gs + V_gs(E=[0,0,0], B=[0,0,0], delta=[0, 0, 0])
eval0, evec0 = H0.eigenstates()
reference_states = evec0  # 長さ3の状態リスト

# === エネルギーリスト（ラベル固定）===
energies = [[], [], []]  # 固定ラベル：index = 0,1,2

for deltaxi in deltax:
    H = H_gs + V_gs(E=[0,0,0], B=[0,0,0], delta=[deltaxi, 0, 0])
    evals, evecs = H.eigenstates()

    # 各状態とのオーバーラップを評価し、参照と最も近い状態を割当て
    overlaps = np.array([
        [abs(evec.overlap(ref)) for ref in reference_states]
        for evec in evecs
    ])
    #matched_indices = np.argmax(overlaps, axis=1)  # (3,) 配列：evec[i]が参照のどれと近いか
    # 負のオーバーラップをコスト関数として最適な割当（行=ref, 列=evec）
    row_ind, col_ind = linear_sum_assignment(-overlaps)
    # # index固定（matched_indices[i]=j → evec[i]はref[j]に対応）
    # for true_label in range(3):
    #     i = np.argmax(overlaps[true_label])  # ref[true_label]に最も近い evecs[i]
    #     energies[true_label].append(evals[i])
    # 割り当てられたものだけを使ってエネルギー格納
    for true_label, i in zip(row_ind, col_ind):
        energies[true_label].append(evals[i])

# === プロット ===
colors = ['tab:blue', 'tab:orange', 'tab:green']
labels = [r"$m_s = -1$", r"$m_s = 0$", r"$m_s = +1$"]

plt.figure(figsize=(7,5))
for i in range(3):
    plt.plot(xvals, np.array(energies[i])/1e9, label=labels[i], color=colors[i])
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp$ (GHz)")
plt.ylabel(r"Energy $E$ (GHz)")
plt.title("Energy levels vs transverse strain (label-tracked)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 次に、$\theta = 90$ として計算

# %%
# strain list
deltay =  np.linspace(0, 5e9) / d_gs_perp 


# eigenvalues
ee_strain = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, 0], delta=[0,deltayi, 0])).eigenenergies() for deltayi  in deltay]


print(len(ee_strain))

# plot
for i in range(3):
    plt.plot(d_gs_perp * np.sqrt(deltay**2)/1e9, [eei[i]/1e9 for eei in ee_strain]) #eei[i]を 1e9で割ってGHZに換算
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp \mathrm{(GHz)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
plt.show()
# Out:
# 50

# %%
# === delta_perp スキャン定義 ===
delta_range = np.linspace(0, 5e9, 100)  # Hz
deltay = delta_range / d_gs_perp
xvals = d_gs_perp * np.sqrt(deltay**2) / 1e9  # GHz for plotting

# === 基準固有状態の取得（delta = 0）===
H0 = H_gs + V_gs(E=[0,0,0], B=[0,0,0], delta=[0, 0, 0])
eval0, evec0 = H0.eigenstates()
reference_states = evec0  # 長さ3の状態リスト

# # Sz期待値で初期状態のラベルを割当
# sz_vals_0 = [qt.expect(Sz, s) for s in evec0]
# label_map = np.argsort(sz_vals_0)  # small→large ⇒ [-1, 0, +1]
# reference_states = [evec0[i] for i in label_map]  # 長さ3の状態リスト

# === エネルギーリスト（ラベル固定）===
energies = [[], [], []]  # 固定ラベル：index = 0,1,2

for deltayi in deltay:
    H = H_gs + V_gs(E=[0,0,0], B=[0,0,0], delta=[0, deltayi, 0])
    evals, evecs = H.eigenstates()

    # 各状態とのオーバーラップを評価し、参照と最も近い状態を割当て
    overlaps = np.array([
        [abs(evec.overlap(ref)) for ref in reference_states]
        for evec in evecs
    ])
    #matched_indices = np.argmax(overlaps, axis=1)  # (3,) 配列：evec[i]が参照のどれと近いか
    # 負のオーバーラップをコスト関数として最適な割当（行=ref, 列=evec）
    row_ind, col_ind = linear_sum_assignment(-overlaps)
    # # index固定（matched_indices[i]=j → evec[i]はref[j]に対応）
    # for true_label in range(3):
    #     i = np.argmax(overlaps[true_label])  # ref[true_label]に最も近い evecs[i]
    #     energies[true_label].append(evals[i])
    # 割り当てられたものだけを使ってエネルギー格納
    for true_label, i in zip(row_ind, col_ind):
        energies[true_label].append(evals[i])

# === プロット ===
colors = ['tab:blue', 'tab:orange', 'tab:green']
labels = [r"$m_s = -1$", r"$m_s = 0$", r"$m_s = +1$"]

plt.figure(figsize=(7,5))
for i in range(3):
    plt.plot(xvals, np.array(energies[i])/1e9, label=labels[i], color=colors[i])
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp$ (GHz)")
plt.ylabel(r"Energy $E$ (GHz)")
plt.title("Energy levels vs transverse strain (label-tracked)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 最後に、$\theta$ を0~90 (deg )に推移させて計算

# %%
# 度数とラジアン変換テスト

#degrees = 180
#radians = math.radians(degrees)

#print(math.cos(radians))

# strain list
strain_perp = 3.0e9

deltax = []
deltay = []

for degrees in range(0,90):
    radius = math.radians(degrees)
    deltax.append(strain_perp * math.cos(radius)  / d_gs_perp )
    deltay.append(strain_perp * math.sin(radius)  / d_gs_perp )



# eigenvalues
ee_strain = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, 0], delta=[deltaxi, deltayi, 0])).eigenenergies() for deltaxi, deltayi in zip(deltax, deltay)]


degree = np.linspace(0,90,90)
print(len(ee_strain))

# plot
for i in range(3):
    plt.plot(degree, [eei[i]/1e9 for eei in ee_strain]) #eei[i]を 1e9で割ってGHZに換算
plt.xlabel(r"degree $\theta \mathrm{(deg)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
plt.show()
# Out:
# 90

# %% [markdown]
# $\theta$ を推移させたが、計算結果は off-strainの大きさが3[GHz]でのエネルギー固有値である。
#
# つまり、off-axisの角度 $\theta$ の依存性は確認できない。

# %%
# strain list
deltax = deltay = np.linspace(0, 5e9) / np.sqrt(2) / d_gs_perp 


# eigenvalues
ee_strain = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, 0], delta=[deltaxi, deltayi, 0])).eigenenergies() for deltaxi, deltayi in zip(deltax, deltay)]


print(len(ee_strain))

# plot
for i in range(3):
    plt.plot(d_gs_perp * np.sqrt(deltax**2 + deltay**2)/1e9, [eei[i]/1e9 for eei in ee_strain]) #eei[i]を 1e9で割ってGHZに換算
plt.xlabel(r"Strain $d_{gs}^{\perp} \delta_\perp \mathrm{(GHz)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
plt.show()
# Out:
# 50

# %% [markdown]
# 計算結果の図を拡大したもの。
#
# off-strain =~3.0GHz  で　$|m_s=-1>$,$|m_s = 0>$
# とのGSLACが確認できる。

# %% [markdown]
# ##### Dependence on on-axis strain $\delta_{\parallel} \equiv \delta_z$

# %%
# strain list
deltaz = np.linspace(0, 20e9) / np.sqrt(2) / d_gs_para

# eigenvalues
ee_strain = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, 0], delta=[0, 0, deltazi])).eigenenergies() for deltazi in deltaz]

# plot
for i in range(3):
    plt.plot(d_gs_para * deltaz/1e9, [eei[i]/1e9 for eei in ee_strain])
plt.xlabel(r"Strain $d_{gs}^{\parallel} \delta_\parallel \mathrm{(GHz)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
plt.show()

# %% [markdown]
# On-axis方向のstarinをかけた場合の計算結果。
#
# $|m_s = \pm1>$ はともに上昇.
#
# $|m_s = 0>$ は下降.
#
# ESの場合とは異なる傾向

# %% [markdown]
# ##### Dependence on on-axis magnetic field $B_\parallel = B_z$ (zero strain)

# %%
# Bz list
#Bz = np.linspace(1340e-4, 1350e-4) #[T] 
Bz = np.linspace(0000e-4, 3000e-4) #[T]  1Gauss = 1e-4T
deltax = deltay = 0e9 / np.sqrt(2) / d_gs_perp #deltax deltay ともに0

# eigenvalues
ee_Bz = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, Bzi], delta=[deltax, deltay, 0])).eigenenergies() for Bzi in Bz]

# plot
for i in range(3):
    plt.plot(Bz*1e4, [eei[i]/1e9 for eei in ee_Bz]) # Bz*1e4で T→Gauss
plt.xlabel(r"Magnetic field $B_z \mathrm{(G)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
#plt.ylim(-0.76, -0.74)
plt.show()

# %% [markdown]
# ↑No-strain

# %%
# Bz list
#Bz = np.linspace(1340e-4, 1350e-4) #[T] 
Bz = np.linspace(0000e-4, 1500e-4) #[T]  1Gauss = 1e-4T
deltax = deltay = 0e9 / np.sqrt(2) / d_gs_perp #deltax deltay ともに0

# eigenvalues
ee_Bz = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, Bzi], delta=[deltax, deltay, 0])).eigenenergies() for Bzi in Bz]

# plot
for i in range(3):
    plt.plot(Bz*1e4, [eei[i]/1e9 for eei in ee_Bz]) # Bz*1e4で T→Gauss
plt.xlabel(r"Magnetic field $B_z \mathrm{(G)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
#plt.ylim(-0.76, -0.74)
plt.show()

# %% [markdown]
# 図を拡大。

# %% [markdown]
# ##### Dependence on on-axis magnetic field $B_\parallel = B_z$ (Relatively low strain)
#
# Similaly, we can plot energy levels as a function of $B_z$ with relatively low strain $\delta_\perp = 1.685$ GHz [Happacher 2023]. The energy diagram is consistent with [Happacher 2023]. We can find the following fact.
# - Two anti-crossings at ~850 G and 1900 G.

# %%
# Bz list
Bz = np.linspace(1340e-4, 1350e-4) #[T]
Bz = np.linspace(0, 3000e-4) #[T]
#strain_off_axis = 2.0e9
deltax = deltay = 1.685e9 / np.sqrt(2) / d_gs_perp

# eigenvalues
ee_Bz = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, Bzi], delta=[deltax, deltay, 0])).eigenenergies() for Bzi in Bz]

# plot
for i in range(3):
    plt.plot(Bz*1e4, [eei[i]/1e9 for eei in ee_Bz])
plt.xlabel(r"Magnetic field $B_z \mathrm{(G)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
#plt.ylim(-0.76, -0.74)
plt.show()

#磁場と少しのstrainを含んだ場合のエネルー準位をプロット

# %% [markdown]
# ##### Dependence on on-axis magnetic field $B_\parallel = B_z$ (Relatively high strain)
#
# Also similaly, we can plot energy levels as a function of $B_z$ with relatively high strain $\delta_\perp = 55.9$ GHz [Happacher 2022]. The result is consistent with [Happacher 2022]. We can find the following facts.
# - ESLAC occurs at 320 G and 512 G
# - At ESLAC1 at 320 G, $|E_1\rangle$ and $|E_2\rangle$ have similar energy levels as a result of mixing of $|E_y, 0\rangle$ and $|E_y, -1\rangle$.
# - At ESLAC2 at 512 G, $|E_x\rangle$ and $|A_1\rangle$ have similar energy levels as a result of mixing of $|E_x, 0\rangle$ and $|E_y, -1\rangle$

# %%
# Bz list
Bz = np.linspace(0, 1000e-4) #[T]
deltax = deltay = 55.9e9 / np.sqrt(2) / d_gs_perp

# eigenvalues
ee_Bz = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, Bzi], delta=[deltax, deltay, 0])).eigenenergies() for Bzi in Bz]

# plot
for i in range(3):
    plt.plot(Bz*1e4, [eei[i]/1e9 for eei in ee_Bz])
plt.xlabel(r"Magnetic field $B_z \mathrm{(G)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
#plt.ylim(50, 60)
plt.show()

# %%
# Bz list
Bx = By = np.linspace(0, 1000e-4) / np.sqrt(2) #[T]
deltax = deltay = 55.9e9 / np.sqrt(2) / d_gs_perp

# eigenvalues
ee_B_off = [(H_gs + V_gs(E=[0, 0, 0], B=[Bxi, Byi, 0], delta=[0, 0, 0])).eigenenergies() for Bxi,Byi in zip(Bx,By)]

# plot
for i in range(3):
    plt.plot((Bx**2 + By**2)*1e4, [eei[i]/1e9 for eei in ee_Bz])
plt.xlabel(r"Magnetic field $B off axis \mathrm{(G)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
#plt.ylim(50, 60)
plt.show()

# %%
bz_list = np.linspace(0, 1500e-4, 100)  # [T]
delta_perp_list = np.linspace(0, 3e9, 100)  # [Hz]
# グリッド作成
bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)
energy_diff = np.zeros_like(bz_mesh)
# スキャン
for i in range(bz_mesh.shape[0]):
    for j in range(bz_mesh.shape[1]):
        bz = bz_mesh[i, j]
        delta = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
        delta_vec = [delta, delta, 0]  # 横方向ストレインのみ
        H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
        eigvals = np.sort(H.eigenenergies())
        # E_{-1} ≈ 最小, E_0 ≈ 中央と仮定
        energy_diff[i, j] = np.abs(eigvals[1] - eigvals[0])
# 描画
plt.figure(figsize=(6,5))
im = plt.imshow(
    energy_diff / 1e6,  # MHz
    extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9, bz_list[0]*1e4, bz_list[-1]*1e4],
    origin='lower',
    aspect='auto',
    cmap='viridis_r'
)
plt.colorbar(im, label=r"$|E_{-1} - E_0|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Energy gap $|E_{-1} - E_0|$ map")
plt.show()

# %%
bz_list = np.linspace(0, 1500e-4, 100)  # [T]
delta_perp_list = np.linspace(0, 3e9, 100)  # [Hz]
# グリッド作成
bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)
energy_diff = np.zeros_like(bz_mesh)
# スキャン
for i in range(bz_mesh.shape[0]):
    for j in range(bz_mesh.shape[1]):
        bz = bz_mesh[i, j]
        delta = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
        delta_vec = [delta, delta, 0]  # 横方向ストレインのみ
        H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
        eigvals = np.sort(H.eigenenergies())
        # E_{-1} ≈ 最小, E_0 ≈ 中央と仮定
        energy_diff[i, j] = np.abs(eigvals[2] - eigvals[1])
# 描画
plt.figure(figsize=(6,5))
im = plt.imshow(
    energy_diff / 1e6,  # MHz
    extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9, bz_list[0]*1e4, bz_list[-1]*1e4],
    origin='lower',
    aspect='auto',
    cmap='viridis_r'
)
plt.colorbar(im, label=r"$|E_{+1} - E_0|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Energy gap $|E_{+1} - E_0|$ map")
plt.show()

# %%
bz_list = np.linspace(0, 1500e-4, 100)  # [T]
delta_perp_list = np.linspace(0, 3e9, 100)  # [Hz]
# グリッド作成
bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)
energy_diff = np.zeros_like(bz_mesh)
# スキャン
for i in range(bz_mesh.shape[0]):
    for j in range(bz_mesh.shape[1]):
        bz = bz_mesh[i, j]
        delta = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
        delta_vec = [delta, delta, 0]  # 横方向ストレインのみ
        H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
        eigvals = np.sort(H.eigenenergies())
        # E_{-1} ≈ 最小, E_0 ≈ 中央と仮定
        energy_diff[i, j] = np.abs(eigvals[2] - eigvals[0])
# 描画
plt.figure(figsize=(6,5))
im = plt.imshow(
    energy_diff / 1e6,  # MHz
    extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9, bz_list[0]*1e4, bz_list[-1]*1e4],
    origin='lower',
    aspect='auto',
    cmap='viridis_r'
)
plt.colorbar(im, label=r"$|E_{+1} - E_{-1}|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Energy gap $|E_{+1} - E_{-1}|$ map")
plt.show()

# %%
bz_list = np.linspace(0, 1500e-4, 100)  # [T]
delta_perp_list = np.linspace(1e6, 3e9, 100)  # [Hz]
# グリッド作成
bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)
energy_diff = np.zeros_like(bz_mesh)
# スキャン
for i in range(bz_mesh.shape[0]):
    for j in range(bz_mesh.shape[1]):
        bz = bz_mesh[i, j]
        delta = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
        delta_vec = [delta, delta, 0]  # 横方向ストレインのみ
        H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
        # eigvals = np.sort(H.eigenenergies())
        # # E_{-1} ≈ 最小, E_0 ≈ 中央と仮定
        # energy_diff[i, j] = np.abs(eigvals[1] - eigvals[0])
        
        eigvals, eigvecs = H.eigenstates()
        # Sz期待値から m_s = 0, -1 を同定
        sz_expect = np.array([expect(Sz, psi) for psi in eigvecs])
        idx_m0 = np.argmin(np.abs(sz_expect - 0))
        idx_m1 = np.argmin(np.abs(sz_expect + 1))  # "-1" に近いもの
        energy_diff[i, j] = np.abs(eigvals[idx_m1] - eigvals[idx_m0])
        energy_diff[energy_diff > 300e6] = np.nan  # 500 MHz 超えを NaN に

#
# 描画
plt.figure(figsize=(6,5))
im = plt.imshow(
    energy_diff / 1e6,  # MHz
    extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9, bz_list[0]*1e4, bz_list[-1]*1e4],
    origin='lower',
    aspect='auto',
    cmap='viridis_r'
)
plt.colorbar(im, label=r"$|E_{-1} - E_0|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Energy gap $|E_{-1} - E_0|$ map")
plt.show()

# %%
# Bz list
Bz = np.linspace(0, 1500e-4) #[T]
deltax = deltay = 0.5e9 / np.sqrt(2) / d_gs_perp

# eigenvalues
ee_Bz = [(H_gs + V_gs(E=[0, 0, 0], B=[0, 0, Bzi], delta=[deltax, deltay, 0])).eigenenergies() for Bzi in Bz]

# plot
for i in range(3):
    plt.plot(Bz*1e4, [eei[i]/1e9 for eei in ee_Bz])
plt.xlabel(r"Magnetic field $B_z \mathrm{(G)}$")
plt.ylabel(r"Energy $E \mathrm{(GHz)}$")
#plt.ylim(50, 60)
plt.show()

# %%
# Bz sweep
Bz = np.linspace(0, 1500e-4, 200)
deltax = deltay = 0.5e9 / np.sqrt(2) / d_gs_perp

energies_m0 = []
energies_m1 = []

for bz in Bz:
    H = H_gs + V_gs(E=[0, 0, 0], B=[0, 0, bz], delta=[deltax, deltay, 0])
    evals, evecs = H.eigenstates()
    sz_exp = np.array([expect(Sz, psi) for psi in evecs])
    idx_m0 = np.argmin(np.abs(sz_exp - 0))
    idx_m1 = np.argmin(np.abs(sz_exp + 1))
    energies_m0.append(evals[idx_m0])
    energies_m1.append(evals[idx_m1])

plt.plot(Bz*1e4, np.array(energies_m0)/1e9, label=r"$m_s=0$")
plt.plot(Bz*1e4, np.array(energies_m1)/1e9, label=r"$m_s=-1$")
plt.xlabel(r"Magnetic field $B_z$ (G)")
plt.ylabel(r"Energy $E$ (GHz)")
plt.legend()
plt.show()

# %%
# パラメータ設定
bz_list = np.linspace(0, 3000e-4, 200)  # [T]
delta_perp_list = np.linspace(1e6, 3e9, 100)  # [Hz]
delta_z_list = np.linspace(0, 10e9, 1)  # [Hz] = 0~10 GHz

bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)

# 描画準備
fig, ax = plt.subplots(figsize=(7, 6))
cmap = plt.cm.get_cmap("viridis", len(delta_z_list))  # 離散カラーマップ

# 各 δz についてループ
for idx, delta_z in enumerate(delta_z_list):
    mask = np.full_like(bz_mesh, np.nan)  # NaNで初期化

    for i in range(bz_mesh.shape[0]):
        for j in range(bz_mesh.shape[1]):
            bz = bz_mesh[i, j]
            delta_perp = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
            delta_z_eff = delta_z / d_gs_para
            delta_vec = [delta_perp, delta_perp, delta_z_eff]

            H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
            eigvals, eigvecs = H.eigenstates()
            sz_expect = np.array([expect(Sz, psi) for psi in eigvecs])
            idx_m0 = np.argmin(np.abs(sz_expect - 0))
            idx_m1 = np.argmin(np.abs(sz_expect + 1))

            diff = np.abs(eigvals[idx_m1] - eigvals[idx_m0])
            if diff < 300e6:
                mask[i, j] = idx  # delta_z のインデックス番号で表示

    # 重ね描き（alphaで半透明）
    im = ax.imshow(
        mask,
        extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9,
                bz_list[0]*1e4, bz_list[-1]*1e4],
        origin='lower',
        aspect='auto',
        cmap=cmap,
        alpha=0.8,
        interpolation='none',
        vmin=0,
        vmax=len(delta_z_list)-1
    )

# 軸と凡例
cbar = fig.colorbar(im, ax=ax, ticks=range(len(delta_z_list)))
cbar.set_label(r"$\delta_z$ (GHz)")
cbar.set_ticks(range(len(delta_z_list)))
cbar.set_ticklabels([f"{z/1e9:.0f}" for z in delta_z_list])

ax.set_xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
ax.set_ylabel(r"Magnetic field $B_z$ (G)")
ax.set_title(r"Overlay of $|E_{-1} - E_0| < 300$ MHz for $\delta_z = 0 \sim 10$ GHz")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Tsuchiya Saki\AppData\Local\Temp\ipykernel_32128\1135670732.py:10: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("viridis", len(delta_z_list))  # 離散カラーマップ

# %%
# === パラメータ ===
bz_list = np.linspace(0, 7000e-4, 100)  # T
delta_perp_list = np.linspace(0, 10e9, 100)  # Hz
delta_z_list = np.linspace(0, 10e9, 2)  # Hz（0～10GHz）

bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)
combined_map = np.full_like(bz_mesh, np.nan)  # NaNで初期化（最終的な結果格納）

# === delta_z sweep ===
for delta_z in delta_z_list:
    temp_map = np.full_like(bz_mesh, np.nan)

    for i in range(bz_mesh.shape[0]):
        for j in range(bz_mesh.shape[1]):
            bz = bz_mesh[i, j]
            delta_perp = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
            delta_z_eff = delta_z / d_gs_para
            delta_vec = [delta_perp, delta_perp, delta_z_eff]

            H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
            eigvals, eigvecs = H.eigenstates()
            sz_expect = np.array([expect(Sz, psi) for psi in eigvecs])
            idx_m0 = np.argmin(np.abs(sz_expect - 0))
            idx_m1 = np.argmin(np.abs(sz_expect + 1))
            diff = np.abs(eigvals[idx_m1] - eigvals[idx_m0])

            if diff < 300e6:
                temp_map[i, j] = diff
            else:
                temp_map[i, j] = np.nan

    # 最小値で上書き（よりエネルギー差が小さい条件を優先）
    # mask = ~np.isnan(temp_map)
    # combined_map[mask] = np.minimum(np.nan_to_num(combined_map[mask], nan=np.inf), temp_map[mask])
    combined_map = temp_map

# === 描画 ===
plt.figure(figsize=(7, 6))
im = plt.imshow(
    combined_map / 1e6,  # MHz表示
    extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9,
            bz_list[0]*1e4, bz_list[-1]*1e4],
    origin='lower',
    aspect='auto',
    cmap='viridis_r',
    vmin=0, vmax=300  # 固定スケール 0–300 MHz
)
plt.colorbar(im, label=r"$|E_{-1} - E_0|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Minimum $|E_{-1} - E_0|$ map over $\delta_z = 0 \sim 10$ GHz")
plt.tight_layout()
plt.show()

# %%
# === パラメータ ===
bz_list = np.arange(0, 7000e-4, 7000e-6)  # T
delta_perp_list = np.arange(0, 10e9, 10e7)  # Hz
delta_z_list = np.linspace(0, 10e9, 1)  # Hz（0～10GHz）

bz_mesh, delta_mesh = np.meshgrid(bz_list, delta_perp_list)
combined_map = np.full_like(bz_mesh, np.nan)  # NaNで初期化（最終的な結果格納）

plt.figure(figsize=(7,6))

for delta_z in delta_z_list:
    temp_map = np.full_like(bz_mesh, np.nan)

    for i in range(bz_mesh.shape[0]):
        for j in range(bz_mesh.shape[1]):
            bz = bz_mesh[i, j]
            delta_perp = delta_mesh[i, j] / np.sqrt(2) / d_gs_perp
            delta_z_eff = delta_z / d_gs_para
            delta_vec = [delta_perp, delta_perp, delta_z_eff]

            H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
            eigvals, eigvecs = H.eigenstates()
            sz_expect = np.array([expect(Sz, psi) for psi in eigvecs])
            idx_m0 = np.argmin(np.abs(sz_expect - 0))
            idx_m1 = np.argmin(np.abs(sz_expect + 1))
            diff = np.abs(eigvals[idx_m1] - eigvals[idx_m0])

            if diff < 300e6:
                temp_map[i, j] = diff

    # 各delta_zの結果を透過重ね表示
    im = plt.imshow(
        temp_map / 1e6,
        extent=[delta_perp_list[0]/1e9, delta_perp_list[-1]/1e9,
                bz_list[0]*1e4, bz_list[-1]*1e4],
        # extent=[0, 10, 0, 7000],
        origin='lower',
        aspect='auto',
        cmap='viridis_r',
        vmin=0,
        vmax=300,
        alpha=1,  # 重ね用透過度
        interpolation='none'
    )

plt.colorbar(im, label=r"$|E_{-1} - E_0|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Overlay of $|E_{-1} - E_0| <$ 300 MHz for $\delta_z = 0 \sim 10$ GHz")
plt.tight_layout()
plt.show()

# %%
# === パラメータ設定 ===
bz_list = np.arange(0, 15000e-4, 15000e-6)           # T
delta_perp_list = np.arange(0, 30e9, 30e7)         # Hz
delta_z_list = np.linspace(0, 10e9, 2)             # Hz

# 描画用の軸 (GHz, G)
x = delta_perp_list / 1e9
y = bz_list * 1e4

# 描画開始
plt.figure(figsize=(7,6))

# delta_zごとに計算して重ね描き
for delta_z in delta_z_list:
    temp_map = np.full((len(delta_perp_list), len(bz_list)), np.nan)

    for i, delta in enumerate(delta_perp_list):
        for j, bz in enumerate(bz_list):
            delta_perp = delta / np.sqrt(2) / d_gs_perp
            delta_z_eff = delta_z / d_gs_para
            delta_vec = [delta_perp, delta_perp, delta_z_eff]

            H = H_gs + V_gs([0, 0, 0], [0, 0, bz], delta_vec)
            eigvals, eigvecs = H.eigenstates()
            sz_expect = np.array([expect(Sz, psi) for psi in eigvecs])

            idx_m0 = np.argmin(np.abs(sz_expect - 0))
            idx_m1 = np.argmin(np.abs(sz_expect + 1))
            diff = np.abs(eigvals[idx_m1] - eigvals[idx_m0])

            if diff < 300e6:
                temp_map[i, j] = diff

    # 描画（pcolormeshはX, Yのmeshgridを自動処理）
    pcm = plt.pcolormesh(
        x, y, temp_map.T / 1e6,  # Tで転置して x→列, y→行
        cmap='viridis_r', vmin=0, vmax=300,
        shading='auto', alpha=1
    )

# カラーバー・ラベル
plt.colorbar(pcm, label=r"$|E_{-1} - E_0|$ (MHz)")
plt.xlabel(r"Transverse strain $\delta_\perp$ (GHz)")
plt.ylabel(r"Magnetic field $B_z$ (G)")
plt.title(r"Overlay of $|E_{-1} - E_0| <$ 300 MHz for $\delta_z = 0 \sim 10$ GHz")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Summary of GSLAC points

# %% [markdown]
# Work in progress
#
# |Strain $\delta_\perp$  | Magnetic field $B_z $ |
# | ----- | ------- |
# | ~4 GHz | 0 G|
# |  0 GHz | 1000 G|
# | 1.685 GHz | ~950 G |

# %% [markdown]
# GSLACKが生じる条件を磁場、strainごとに見てきた。

# %% [markdown]
# We can calculate the magnetic field values that cause ESLAC under various strain values using the program that we develop later on. The result agrees well with that in [Happacher 2022].
#
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=https://drive.google.com/uc?id=11arpfSSwNJW3u8UgsPGncubWAR3KrHE7 witdh="100">
# </div>
# <center>Figure: Level anti-crossing </center>

# %% [markdown]
# ### Decomposition of excited eigenstates into spin quantumm basis
#
# For the NV-EIT to work, a coherent mixing between $\Delta m_s = \pm 1$ needs to occur. For the strain-induced or ESLAC-induced EIT, we make sure that the excited state consists of multiple spin quantum states. Thus, we decompose the excited states into the spin quantum number basis.
#
# The eigenstate basis is $\{|\psi_{es} \rangle \} = (|A_2\rangle, |A_1\rangle, |E_x\rangle, |E_y\rangle, |E_2\rangle, |E_1\rangle)$. The spin quantum number basis is $\{|\sigma_{es} \rangle \} = (|E_x, +1\rangle, |E_x, 0\rangle, |E_x, -1\rangle, |E_y, +1\rangle, |E_y, 0 \rangle, |E_y, -1\rangle)$.

# %% [markdown]
# #### Program to calculate the degree of mixture

# %% [markdown]
# The function "number_basis_tomography" in the next code block calculates the degree of mixture of the spin qunatum states for each excted eigenstate, i.e., $|\langle \sigma_{es} | \psi_{es} \rangle|^2$.

# %%
def number_basis_tomography(H_tot):
    ee, ev = H_tot.eigenstates()
    ev_amp = [abs(evi.full())**2 for evi in ev][::-1]
    #配列の中に、各スピン状態の確率振幅の二乗を格納
    #インデックス::-1は不明


    xlabels = [r'$|E_x, 1\rangle$', r'$|E_x, 0\rangle$', r'$|E_x, -1\rangle$', r'$|E_y, 1\rangle$', r'$|E_y, 0\rangle$', r'$|E_y, -1\rangle$']
    ylabels = [r'$|E_2\rangle$', r'$|E_1\rangle$', r'$|E_y\rangle$', r'$|E_x\rangle$', r'$|A_1\rangle$', r'$|A_2\rangle$'][::-1]
    plt.imshow(ev_amp, cmap='Blues')
    plt.colorbar()
    plt.gca().xaxis.set_ticks_position('top')
    plt.xticks(ticks=np.arange(len(xlabels)), labels=xlabels)
    plt.yticks(ticks=np.arange(len(ylabels)), labels=ylabels)
    plt.show()

    return 0

# %% [markdown]
# #### Degree of mixture under various $\vec{B}$ and $\vec{\delta}$

# %% [markdown]
# ##### Zero-field, zero-strain: $\vec{B} = 0$, $\vec{\delta} = 0$
#
# First, we try a trivial case of $\vec{B} = 0$ and $\vec{\delta} = 0$. One can observe the following facts.
# - $|A_2 \rangle$ and $|A_1 \rangle$ states consists of the $m_s = \pm 1$ spin bases, which were not used in the past NV-EIT experiments except for [Togan 2010] [Togan 2011].
# - $|E_x\rangle$ and $|E_y\rangle $ largely preserve the spin $m_s = 0$, but also mixes $m_s = \pm 1$ weakly.
# - $|E_1\rangle$ and $|E_2\rangle $ mix $m_s = \pm 1$, but not with equal populations.

# %%
H_tot = H_es + V_es(E=[0, 0, 0], B=[0, 0, 0], delta=[0, 0, 0])
number_basis_tomography(H_tot)
qt.plot_energy_levels([H_tot],show_ylabels=True,figsize=(2, 3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 H_tot = H_es + V_es(E=[0, 0, 0], B=[0, 0, 0], delta=[0, 0, 0])
#       2 number_basis_tomography(H_tot)
# ----> 3 qt.plot_energy_levels([H_tot],show_ylabels=True,figsize=(2, 3))
#
# TypeError: plot_energy_levels() got an unexpected keyword argument 'show_ylabels'

# %% [markdown]
# strainがかかってないので、縦軸の$|E_x>、|E_y>、|E_1>、|E_2>$の結果は自明(２重縮退)である。
#
# すなわち、$E_x$と$E_y$の区別ができない状況である。
#
# 図示すると下記のようになる。(２重縮退を内在する準位が3つであってるかな)

# %%
H_tot = H_es + V_es(E=[0, 0, 0], B=[0, 0, 10000e-4], delta=[0, 0, 0])
number_basis_tomography(H_tot)
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3))
# Out:
# 0

# %% [markdown]
# ↑試しに1Tの外部磁場を加えてみた(正常ゼーマン効果)。
# strainによる2重の縮退が解けず、スピン量子数により一意に状態を指定できるのが確かにわかる。

# %% [markdown]
# ##### Strain-induced mixing: $\vec{B} = 0, d_{es}^{\perp} \delta^{\perp} = 8 $ GHz
#
#
# Next, let us look at the case of a typical strain of $d_{es}^{\perp} \delta^{\perp} = 8 $ GHz. In this case,
#
# - $|A_2\rangle $ and $|A_1\rangle$ mix $m_s = \pm 1$ states equally, but the orbital part exhibit asymmetry, i.e., $|E_x, 1\rangle$ and $|E_y, 1\rangle$.
# - $|E_x\rangle$ still maintains the spin $m_s = 0$, but $|E_y\rangle$ mixes all spin numbers.
# - $|E_1\rangle$ keeps $m_s = 0$ relatively, while $|E_2\rangle$ mixes $m_s = \pm 1$ relatively.

# %%
deltax = deltay = 8e9/des_perp/np.sqrt(2) # Hz
B_perp = 0e-4 # T
B_z = 0e-4 # T

H_tot = H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_z], delta=[deltax, deltay, 0])
number_basis_tomography(H_tot)
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3))
# Out:
# 0

# %% [markdown]
# ##### ESLACy-induced mixing: $B_z = 850$ G, $\delta_\perp = 1.685$ GHz
#
# Let us look at a case with a magnetic field of 850 G.
#
# - $|E_1\rangle$ and $|E_2\rangle$ have both of $m_s = 0$ and $m_s = -1$ components.
# - Other basis maintain each spin basis.

# %%
deltax = deltay = 1.685e9 / np.sqrt(2) / des_perp
B_perp = 0e-4 # T
B_z = 850e-4 # T

H_tot = H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_z], delta=[deltax, deltay, 0])
number_basis_tomography(H_tot)
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3))
# Out:
# 0

# %% [markdown]
# ##### ESLACy-induced mixing: $B_z = 320$ G, $\delta_\perp = 55.9$ GHz
#
# Let us look at a case with a magnetic field of 320 G.
#
# - $|E_1\rangle$ and $|E_2\rangle$ have both of $m_s = 0$ and $m_s = -1$ components.
# - Other basis maintain each spin basis.

# %%
deltax = deltay = 55.9e9 / np.sqrt(2) / des_perp
B_perp = 0e-4 # T
B_z = 320e-4 # T

H_tot = H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_z], delta=[deltax, deltay, 0])
number_basis_tomography(H_tot)
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3))
# Out:
# 0

# %% [markdown]
# ##### ESLACx-induced mixing: $B_z = 512$ G, $\delta_\perp = 55.9$ GHz
#
# Finally, let us look at a case with a magnetic field of 512 G.
#
# - $|A_1\rangle$ and $|E_x\rangle$ have $m_s = 0$ and $m_s = -1$ components.
# - Other basis maintain each spin basis, but the assignment differs to 320 G case.

# %%
deltax = deltay = 55.9e9 / np.sqrt(2) / des_perp
B_perp = 0e-4 # T
B_z = 512e-4 # T

H_tot = H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_z], delta=[deltax, deltay, 0])
number_basis_tomography(H_tot)
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3))
# Out:
# 0

# %% [markdown]
# #### Summary of spin quntum numbers that are coherently mixed at various $B_\parallel$ and $\delta_\perp$ conditions
#
# |  | $B_z = 0$ G | $B_z = 320$ G | $B_z = 512$ G | $B_z = 850$ G | $B_z = 1240$ G | $B_z = 1900$ G |
# | ----- | ------- | ------- | ------- | ------- | ------- | ------- |
# | Zero strain | -------------------------------- | -------------------------------- | -------------------------------- | -------------------------------- | $|E_x, 1\rangle$, $|E_x, 0\rangle$, $|E_y, 1\rangle$, $|E_y, 0\rangle$ | -------------------------------- |
# | Low strain | $|E_x, $  $|E_y, -1\rangle$, $|E_y, 0\rangle$, $|E_y, 1\rangle$ | -------------------------------- | -------------------------------- | | $|E_y, 1\rangle$, $|E_y, 0\rangle$ | ???? |
# | High strain | -------------------------------- | $|E_y, 0\rangle$, $|E_y, -1\rangle$ | $|E_x, 0\rangle$, $|E_x, -1\rangle$ | -------------------------------- | -------------------------------- | -------------------------------- |

# %% [markdown]
# -----> Want to plot 50-50 mixing as a function of field and strain.

# %% [markdown]
# ### Candidate ESLAC conditions for higher EIT signal
#
# From the analysis above, we have found conditions of $B_z$ and $\delta_\perp$ that provide equal mixing of spin numbers in an eignestate. This section list such conditions.

# %% [markdown]
# #### Mixing between $m_s = +1$ and $-1$
#
# - $A_1$: $B_z = 0$ G, $\delta_\perp = 0$ GHz
# - $A_2$: $B_z = 0$ G, $\delta_\perp = 0$ GHz

# %% [markdown]
# #### Mixing between $m_s = 0$ and $+1$
#
# - $B_z = XX$ G, $\delta = XX$ GHz

# %% [markdown]
# #### Mixing between $m_s = 0$ and $-1$
#
# - $B_z = XX$ G, $\delta = XX$ GHz

# %% [markdown]
# ## Sub issue 2: How robust is the ESLACx-induced EIT against perturbations of $B$ and $\delta$?
#
#
# In sub issue 1, we have identified candidate ESLAC conditions that can potentially provide stronger EIT signal. In this sub issue 2, we would like to evaluate (i) whether this condition is easy to realize experimentally, and (ii) how much EIT signal contrast is expected. For (i), we list the experimental conditions that may affect the EIT signal. If EIT signal is sensitive to these conditions, it would be difficult to conduct experiments. For (ii), we use the Schroedinger equation to numerically simulate CPT.

# %% [markdown]
# ### Factors that affect EIT signal
#
# Here I would like to list the factors that deptermine the EIT signal contrast.
#
# - Degree of mixture of spin numbers (discussed in sub issue 1)
# - Change of degree of mixing agains perturbations
# - XXXX

# %% [markdown]
# #### Definition of degree of mixing
#
# First, we need to check how robus this ESLAC is against small perturbations of an additional magnetic field and a strain.

# %% [markdown]
# We are interested in evaluating the following components:
# - $\rho^{E_y}_{m_s = 0} = |\langle E_y|E_y, 0\rangle |^2 + |\langle E_y|E_x, 0\rangle |^2$
# - $\rho^{E_y}_{m_s = -1} = |\langle E_y|E_y, -1\rangle |^2 + |\langle E_y|E_x, -1\rangle |^2$

# %% [markdown]
# strainが無いので$|E_x>、|E_y>$の両方の内積を考える必要がある。
# (なぜ、$E_y$だけを考慮しているのか)

# %% [markdown]
# #### Definition of change of degree of mixing
#
# - $ \frac{d\rho}{dB_z}$
# - $ \frac{d\rho}{d\delta_\perp}$

# %% [markdown]
# On-axis方向の磁場、off-axisのstrainに対して、準位$E_y$に電子が存在する確率がどう変化をするのかを、
#
# この定義式が示す。

# %% [markdown]
# ### Change of degree of mixing against perturbations of $B$ and $\delta$
#
# Here we examine to what extent the degree of mixing changes as a function of magnetic field and strain.

# %% [markdown]
# #### Magnetic field $B_z$
#
# We calculate $\rho$ as a function of magnetic field under zero-strain. One can obsereve the following facts.
# - The mixing balance of $m_s = 1$ and $m_s = 0$ at $|E_y\rangle$ is max at ~ 1254 G
# - If one stabilizes $B_z$ within $\pm$ 20 G, the balance remains within 0.4 ~ 0.6
# - The symmetry brakes down at ~1340 G, probably due to the change of enegy level order.

# %%
delta_x = delta_y = 55.9e9 / np.sqrt(2) / des_perp # Hz
B_perp = 0 # T
B_z = np.linspace(500e-4, 540e-4) # T

ev_amp = [abs((H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_zi], delta=[delta_x, delta_y, 0])).eigenstates()[1][3].full())**2 for B_zi in B_z]
rho_1 = [ev_ampi[2] + ev_ampi[5] for ev_ampi in ev_amp]
rho_0 = [ev_ampi[1] + ev_ampi[4] for ev_ampi in ev_amp]
plt.plot(B_z*1e4, rho_1, label=r"$\rho_{m_s=1}^{E_y}$")
plt.plot(B_z*1e4, rho_0, label=r"$\rho_{m_s=0}^{E_y}$")
plt.xlabel(r"$B_z \mathrm{(G)}$")
plt.ylabel(r"$\rho^{E_y}$")
plt.legend()

plt.show()

# %% [markdown]
# 比較的大きいstrainと外部磁場を摂動した
#
# $m_s = 1$のグラフが、B=500Gaussで低い値をとるのは

# %%
delta_x = delta_y = 55.9e9 / np.sqrt(2) / des_perp # Hz
B_perp = 0 # T
B_z = np.linspace(500e-4, 540e-4) # T

ev_amp = [abs((H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_zi], delta=[0, 0, 0])).eigenstates()[1][3].full())**2 for B_zi in B_z]
rho_1 = [ev_ampi[0] + ev_ampi[3] for ev_ampi in ev_amp]
rho_0 = [ev_ampi[1] + ev_ampi[4] for ev_ampi in ev_amp]
rho_m1 = [ev_ampi[2] + ev_ampi[5] for ev_ampi in ev_amp]

plt.plot(B_z*1e4, rho_1, label=r"$\rho_{m_s=1}^{E_y}$")
plt.plot(B_z*1e4, rho_0, label=r"$\rho_{m_s=0}^{E_y}$")
#plt.plot(B_z*1e4, rho_m1, label=r"$\rho_{m_s=-1}^{E_y}$")
plt.xlabel(r"$B_z \mathrm{(G)}$")
plt.ylabel(r"$\rho^{E_y}$")
plt.legend()

plt.show()

# %% [markdown]
# #### Strain $\delta_\perp$
# We calculate $\rho$ as a funtion of strain. One can find the following things.
# - The mixing balance is stable at less than 100 MHz strain
# - The $m_s=0$ ratio goes to 0 while $m_s=1$ ratio goes to 1 at strain of ~10 GHz

# %%
de_perp_delta_perp = np.linspace(1e6, 1e9) # Hz
delta_x = delta_y = de_perp_delta_perp/des_perp/np.sqrt(2) # Hz
B_perp = 0e-4 # T
B_z = 1254e-4 # T

ev_amp = [abs((H_es + V_es(E=[0, 0, 0], B=[B_perp, B_perp, B_z], delta=[delta_xi, delta_yi, 0])).eigenstates()[1][2].full())**2 for delta_xi, delta_yi in zip(delta_x, delta_y)]
#strainに対応するトータルのハミルトニアンの確率振幅の二乗を格納
rho_1 = [ev_ampi[0] + ev_ampi[3] for ev_ampi in ev_amp]
rho_0 = [ev_ampi[1] + ev_ampi[4] for ev_ampi in ev_amp]
plt.plot(de_perp_delta_perp/1e9, rho_1, label=r"$\rho_{m_s=1}^{E_y}$")
plt.plot(de_perp_delta_perp/1e9, rho_0, label=r"$\rho_{ms=0}^{E_y}$")
plt.xlabel(r"$d_{es}^{\perp} \delta_\perp \mathrm{(GHz)}$")
plt.ylabel(r"$\rho^{E_y}$")
plt.legend()

plt.show()

# %% [markdown]
# ### Numerical simulation of Coherent Population Trapping (work in progress)
#
#
# Here, we are going to see if coherent population trapping happens at the conditions that we saw in the previous section.

# %% [markdown]
# #### Schrödinger equation construction
# First, we need to construct the ground state triplet Hamiltonian without nuclear spin.

# %%
# Physics constant
Dgs = 2.87e9                # Hz       # [Doherty 2013]
dgs_para = 0.035            # Hz/(V/m) # [Doherty 2013]
dgs_perp = 0.17             # Hz/(V/m) # [Doherty 2013]
ggs_para = 2.0028           # 1        # [Doherty 2013]
ggs_perp = 2.0028           # 1        # [Doherty 2013]

# %% [markdown]
# The ground state Hamiltonian is numerically defined as follows.

# %%
# bare Hamiltonian
H_gs = Dgs * (Sz**2 - 1 * (1 + 1)/3 * S0)

# Interaction Hamiltonian
def V_gs(E, B, delta):
    return muB * ggs_para * Sz * B[2] \
           + muB * ggs_perp * (Sx * B[0] + Sy * B[1]) \
           + dgs_para * (E[2] + delta[2]) * (Sz**2 - 1 * (1 + 1)/3 * S0) \
           + dgs_perp * (E[0] + delta[0]) * (Sy**2 - Sx**2) \
           + dgs_perp * (E[1] + delta[1]) * (Sx * Sy + Sy * Sx)

# %% [markdown]
# We can check the ground state energy levels quickly.

# %%
# plot energy levels
E = [0, 0, 0] # V/m
B = [0, 0, 100e-4] # T
delta = [0.75e10/des_para/np.sqrt(2), 0.75e10/des_para/np.sqrt(2), 0] # Hz

H_tot = H_gs + V_gs(E, B, delta)
qt.plot_energy_levels([H_tot], h_labels=None, energy_levels=None, N=0, fig=None, ax=None) #qutip 5.0
#qt.plot_energy_levels([H_tot], show_ylabels=True, figsize=(2, 3)) #qutip 4.0

plt.show()

# %% [markdown]
# Then, we combine ground state Hamiltonian and excited state Hamiltonian as follows.
# $$
# H = |^3A_2\rangle\langle^3A_2| \otimes H_{gs} + \omega_z |^3E\rangle\langle^3E| \otimes H_{es}
# =
# \begin{pmatrix}
# H_{gs} & 0 \\
# 0 & \omega_z + H_{es}
# \end{pmatrix}
# $$
#
# $$
# V = |^3A_2\rangle\langle^3A_2| \otimes V_{gs} + |^3E\rangle\langle^3E| \otimes V_{es}
# =
# \begin{pmatrix}
# V_{gs} & 0 \\
# 0 & V_{es}
# \end{pmatrix}
# $$
#
# Here, we defined $\omega_z = c/ZPL = 470$ THz as a ZPL ramor freuquency

# %%
# Define physics constant
c   = 3.0e8  # m/s
ZPL = 637e-9 # m

# full system bare Hamiltonian
H = np.zeros((9, 9), dtype=complex)
H[:3, :3] = H_gs.full()
H[3:, 3:] = H_es.full() + c/ZPL * np.eye(6)
H = qt.Qobj(H)

# full system interaction Hamiltonian
def V(E, B, delta):
    V = np.zeros((9, 9), dtype=complex)
    V[:3, :3] = V_gs(E, B, delta).full()
    V[3:, 3:] = V_es(E, B, delta).full()
    return qt.Qobj(V)

# %% [markdown]
# Then, we represent the incident laser as a complete spin-preserving transition between ground state and excited state.
# $$
# H_{laser} = P \cos (\omega t)\tilde{S}
# $$

# %% [markdown]
# Here, we define the pseudo transition matrix as follows.
# $$
# \tilde{S} = (|^3A_2\rangle\langle^3E_x| + |^3A_2\rangle\langle^3E_y| + |^3E_x\rangle\langle^3A_2| + |^3E_y\rangle\langle^3A_2|) \otimes S_0
# $$

# %%
A2, Ex, Ey = qt.basis(3, 0), qt.basis(3, 1), qt.basis(3, 2)
S_pseudo = qt.Qobj(qt.tensor(A2 * Ex.dag() + A2 * Ey.dag() + Ex * A2.dag() + Ey * A2.dag(), S0).full())

# %% [markdown]
# Here we calculate the population dynamics by master equation in lab frame, as a function of $\vec{E}$, $\vec{B}$, $\vec{\delta}$, $\Omega_c$, $\lambda_c$, $\Omega_p$, $\lambda_p$, $t_{end}$

# %%
def rho_CPT(E, B, delta, P1, lambda1, P2, lambda2, t_end): # E(V/m), B(T), delta(V/m), P(Hz), lambda(m), t_end(s)
  dt = 0.1e-12 # s
  t = np.linspace(0, t_end, int(t_end/dt) + 1)
  H0 = 2*np.pi * (H + V(E, B, delta))
  H1 = 2*np.pi * S_pseudo
  def H1_coeff(t, args):
    return P1 * np.cos(2*np.pi*c/lambda1 * t)
  H2 = 2*np.pi * S_pseudo
  def H2_coeff(t, args):
    return P2 * np.cos(2*np.pi*c/lambda2 * t)
  rho0 = 1/3 * (qt.ket2dm(qt.basis(9, 0)) + qt.ket2dm(qt.basis(9, 1)) + qt.ket2dm(qt.basis(9, 2)))
  result = qt.mesolve([H0, [H1, H1_coeff], [H2, H2_coeff]], rho0, t, options={'progress_bar': 'enhanced'})
  return t, result.states

# %% [markdown]
# Let us calculate some population dynamics.

# %%
# variables
E = [0, 0, 0] # V/m
B = [0, 0, 60e-4] # T
delta = [1e9/des_perp/np.sqrt(2), 1e9/des_perp/np.sqrt(2), 0] # Hz
P1 = 5e9 # Hz
lambda1 = 637e-9 # m
P2 = 0 # Hz
lambda2 = 637e-9 # m
t_end = 1e-9 # s

# calculation
tlist, rho_list = rho_CPT(E, B, delta, P1, lambda1, P2, lambda2, t_end)
# Out:
#  Total run time: 1069.92s

# %%
def plot_number(tlist, rho):
  pop = [[qt.expect(qt.ket2dm(qt.basis(9, i)), rhoi) for i in range(9)] for rhoi in rho]
  for i in range(9):
    plt.plot(tlist, [p[i] for p in pop], label=f"{i+1}")
  plt.legend()
  plt.xlabel("t (s)")
  plt.ylabel("Population")
  plt.show()
  return 0

# %%
plot_number(tlist, rho_list)
# Out:
# 0

# %% [markdown]
# #Rotating wave approximation
# The calculation took tremendous time because we need to prepare $\Delta t = 0.1$ ps for calculation. This is due to that the ZPL ~ 637 nm corresponds to 470 THz ramor precession. For efficient calculation, let us use a rotating frame described as following unitary matrix.
#
# $$
# \begin{align}
# U(t) = e^{i \omega_z|E\rangle\langle E|t} =
# \begin{pmatrix}
# I_3 & 0 \\
# 0 & e^{i\omega_z t} I_6
# \end{pmatrix}
# \end{align}
# Then, the Hamiltonia in the rotating frame becomes as follows.
# \begin{align}
# H_{rot} = &U H U^\dagger - i U \frac{dU^\dagger}{dt} \\
# =
# &\begin{pmatrix}
# I_3 & 0 \\
# 0 & e^{i\omega_z t} I_6
# \end{pmatrix}
# \begin{pmatrix}
# H_{gs} & 0 \\
# 0 & \omega_z + H_{es}
# \end{pmatrix}
# \begin{pmatrix}
# I_3 & 0 \\
# 0 & e^{-i\omega_z t} I_6
# \end{pmatrix}
# -i
# \begin{pmatrix}
# I_3 & 0 \\
# 0 & e^{i\omega_z t} I_6
# \end{pmatrix}
# \frac{d}{dt}
# \begin{pmatrix}
# I_3 & 0 \\
# 0 & e^{-i\omega_z t} I_6
# \end{pmatrix}
# \\
# &+P \cos{\omega_L t}
# \begin{pmatrix}
# I_3 & 0 & 0 \\
# 0 & e^{i\omega_z t} I_3 & 0 \\
# 0 & 0 & e^{i\omega_z t} I_3
# \end{pmatrix}
# \begin{pmatrix}
# 0 & I_3 & I_3 \\
# I_3 & 0 & 0 \\
# I_3 & 0 & 0
# \end{pmatrix}
# \begin{pmatrix}
# I_3 & 0 & 0 \\
# 0 & e^{-i\omega_z t} I_3 & 0 \\
# 0 & 0 & e^{-i\omega_z t}
# \end{pmatrix}
# \\
# =
# &\begin{pmatrix}
# H_{gs} & 0 \\
# 0 & H_{es}
# \end{pmatrix}
# +
# \frac{P}{2}
# \begin{pmatrix}
# 0 & e^{i(\omega_L - \omega_z)t}I_3 & e^{i(\omega_L - \omega_z)t}I_3 \\
# e^{-i(\omega_L - \omega_z)t}I_3 & 0 & 0 \\
# e^{-i(\omega_L - \omega_z)t}I_3 & 0 & 0
# \end{pmatrix}
# \end{align}
# $$

# %% [markdown]
# Note that we used rotating wave approximation here. The state vector in rotating frame becomes as follows.
# $$
# |\psi\rangle_{rot} = U|\psi\rangle
# $$
# The population dynamics wouldn't change in rotating frame because
# $$
# |\langle i|\psi\rangle_{rot}|^2 = \langle i|\psi_{rot}\rangle\langle \psi_{rot}|i\rangle = \langle i| U |\psi\rangle\langle\psi |U^\dagger|i\rangle =
# $$

# %%
def rho_CPT_RWA(E, B, delta, rho_init, P1, lambda1, P2, lambda2, t_end): # E(V/m), B(T), delta(V/m), P(Hz), lambda(m), t_end(s)
  # prepare
  c = 3e8 # m/s
  dt = 0.01e-9 # s
  t = np.linspace(0, t_end, int(t_end/dt) + 1)
  # Hamiltonian and its rotating wave approximation
  H0 = 2*np.pi * (H + V(E, B, delta))
  H0_rot = qt.Qobj(H0.full() - 2*np.pi*c/ZPL*np.diag([0, 0, 0, 1, 1, 1, 1, 1, 1]))
  delta_omega1 = 2*np.pi*c*(1/lambda1 - 1/ZPL)
  delta_omega2 = 2*np.pi*c*(1/lambda2 - 1/ZPL)
  H_up_rot = qt.Qobj(np.kron(np.array([[0, 1, 1], [0, 0, 0], [0, 0, 0]]), np.eye(3)))
  def H_up_rot_coeff(t, args):
    return P1/2 * np.exp(1j*delta_omega1*t) + P2/2 * np.exp(1j*delta_omega2*t)
  H_down_rot = qt.Qobj(np.kron(np.array([[0, 0, 0], [1, 0, 0], [1, 0, 0]]), np.eye(3)))
  def H_down_rot_coeff(t, args):
    return P1/2 * np.exp(-1j*delta_omega1*t) + P2/2 * np.exp(-1j*delta_omega2*t)
  result = qt.mesolve([H0_rot, [H_up_rot, H_up_rot_coeff], [H_down_rot, H_down_rot_coeff]], rho_init, t, options={'progress_bar': 'enhanced', 'rtol': 1e-8, 'atol': 1e-8})
  return t, result.states

# %% [markdown]
# Let us see the population dynamics that we saw above.

# %%
# variables
E = [0, 0, 0] # V/m
B = [0, 0, 60e-4] # T
delta = [1e9/des_perp/np.sqrt(2), 1e9/des_perp/np.sqrt(2), 0] # Hz
rho0 = 1/3 * (qt.ket2dm(qt.basis(9, 0)) + qt.ket2dm(qt.basis(9, 1)) + qt.ket2dm(qt.basis(9, 2)))
P1 = 5e9 # Hz
lambda1 = 637e-9 # m
P2 = 0 # Hz
lambda2 = 637e-9 # m
t_end = 1e-9 # s

# calculation
tlist, rho_list = rho_CPT_RWA(E, B, delta, rho0, P1, lambda1, P2, lambda2, t_end)

# plot
plot_number(tlist, rho_list)
# Out:
#  Total run time:   0.24s
# 0

# %% [markdown]
# The result matches well so let us use RWA form to see CPT.

# %% [markdown]
# #### CPT calculation
# Here, we are going to see CPT.

# %% [markdown]
# Let us use $(d \delta_\perp, B_z) = (8 \mathrm{GHz}, 0 \mathrm{G})$, where [Acosta 2013] succeeded to see EIT.

# %%
# variables
E_CPT = [0, 0, 0] # V/m
B_CPT = [0, 0, 0e-4] # T
delta_CPT = [0e9/des_perp/np.sqrt(2), 0e9/des_perp/np.sqrt(2), 0] # Hz

# %% [markdown]
# The Hamiltonian and its eigenstates obserevable are as follows.

# %%
H_CPT = H + V(E_CPT, B_CPT, delta_CPT)
number_basis_tomography(qt.Qobj(H_CPT[3:, 3:]))
# Out:
# 0

# %% [markdown]
# We need a tool which returns the energy difference corresponding to the two states of our interest.

# %%
def lambda_target(E, B, delta, ni, nf): # the order of  0, -1, 1, E2, E1, Ey, Ex, A1, A2, basically
  H_CPT = H + V(E, B, delta)
  ee, ev = H_CPT.eigenstates()
  return c/(ee[nf-1] - ee[ni-1])

# %% [markdown]
# Let us see some population dynamics based on the eigenstates basis.

# %%
def plot_eigen(E, B, delta, tlist, rho):
  H_CPT = H + V(E, B, delta)
  ee, ev = H_CPT.eigenstates()
  pop = [[qt.expect(qt.ket2dm(evi), rhoi) for evi in ev] for rhoi in rho]
  labels = ["0", "-1", "1", "E2", "E1", "Ey", "Ex", "A1", "A2"]
  for i in range(9):
    plt.plot(tlist, [p[i] for p in pop], label=labels[i])
  plt.legend()
  plt.xlabel("t (s)")
  plt.ylabel("Population")
  plt.show()
  return 0

# %%
# Variables
P1 = 1e9 # Hz
lambda1 = lambda_target(E_CPT, B_CPT, delta_CPT, 2, 7)
P2 = 1e9 # Hz
lambda2 = lambda_target(E_CPT, B_CPT, delta_CPT, 3, 7)
t_end = 10e-9 # s

rho_init = P2/np.sqrt(P1**2 + P2**2) * qt.basis(9, 0) - P1/np.sqrt(P1**2 + P2**2) * qt.basis(9, 2)
#rho_init = rho0

# calculation
tlist, rho_list = rho_CPT_RWA(E_CPT, B_CPT, delta_CPT, rho_init, P1, lambda1, P2, lambda2, t_end)

plot_number(tlist, rho_list)
# Out:
#  Total run time:   1.15s
# 0

# %% [markdown]
# ## Sub issue 3: At which temperature does the ESLAC induced NV-EIT break down?
#
# In this issue 3, we would like to see how robust the EIT signal is against temperature. To carry out this task, we need to use the Master equation to include the phonon effect. Because a recent paper by [Happacher 2023] provides a full description for predicting photoluminescence under intermediate temperature, we first try to reproduce their results of photoluminescence under various temperature and magnetic field conditions. Then, we can incorporate the resonant driving of the lambda system to predict the EIT signal under intermediate temperature.

# %% [markdown]
# #### Master equation incorporating phonon interactions

# %% [markdown]
# Here, we are going to numerically calculate the temperature dependence of ESLAC induced NV-EIT. The simulation tool consists of three parts. The first part is the bare Hamiltonian of $^3A_2$, $^3E$, and $^1A_1 / E_1$, as well as their interaction Hamiltonian. The number of eigenstates is $3 + 6 + 1 = 10$. The Hamiltonians are from [Doherty 2013]. The second part is the spin preserving transitions between $^3A_2$, $^3E$, and $^1A_1 / E_1$. These transition include laser pumping, spontaneous optical decay, and inter sytem crossing. The transitions are expressed as Lindblad operator, whose decay rate is independent on temperature except for the inter sytem crossing rate. The decay rates are from [Happacher 2023]. The third part is the phonon-induced transitions within excited state. The trantision matrices are basically expressed by only $|E_x\rangle$ and $|E_y\rangle$, according to group thoery [Happacher 2023]. Their rates have a strong temperature dependence of $\propto T^5$ [Happacher 2023].
#
# We expect to have the temperature hypothesis as following steps.
# 1. Bulid the model described above
# 1. Prepare initial state on the excited state that spin mixing happens
# 1. Solve the master equation and have coherence time of that state
# 1. Compare the coherence time with low temparature case
#
# These steps are based on the following assumings.
# - EIT robustness is a function of
#   - Incident laser linewidth and power
#   - Excited state eigenstate's spin states balance that we are using
#   - Spontaneous decay rates
#   - ISC decay rates
#   - Photon induced transition within excited states
#   - T1 at ground states
# - Laser linewidth is very narrow enough to make transition only of our interest states
# - We can change laser power as we like
# - Excited state eigenstate's spin states balance are optimized to 50-50
# - Spontaneous decay rates are inpependent on temperature
# - T1 at ground states are independent on temperature

# %% [markdown]
# マスター方程式について
# http://physnakajima.html.xdomain.jp/projection.pdf

# %% [markdown]
# ##### System construction
# First, let us define the basis. We are treating the composite 10 level system as following basis.
# $$
# |1\rangle = |^3A_2,-1\rangle, |2\rangle = |^3A_2,0\rangle, |3\rangle = |^3A_2,1\rangle
# $$
# $$
# |4\rangle = |E_y, -1\rangle, |5\rangle = |E_y, 0\rangle, |6\rangle = |E_y, 1\rangle,|7\rangle = |E_x, -1\rangle,|8\rangle = |E_x, 0\rangle, |9\rangle = |E_x, 1\rangle
# $$
# $$
# |10\rangle = |^1A_1/E_1\rangle
# $$

# %%
def psi(i):
    return qt.basis(10, i-1)

# %% [markdown]
# Constrct the Hamiltonian of the comopsite system as follows.
# $$
# H + V(E, B, \delta) = 2 \pi
# \begin{pmatrix}
# H_{gs} + V_{gs}(E, B, \delta) & 0 & 0 \\
# 0 & H_{es} + V_{es}(E, B, \delta) & 0 \\
# 0 & 0 & 0
# \end{pmatrix}
# $$

# %%
H = np.zeros((10, 10), dtype=complex)
H[:3, :3] = H_gs.full()
H[3:9, 3:9] = H_es.full()
H = 2 * np.pi * qt.Qobj(H)

# %%
def V(E, B, delta):
    V = np.zeros((10, 10), dtype=complex)
    V[:3, :3] = V_gs(E, B, delta).full()
    V[3:9, 3:9] = V_es(E, B, delta).full()
    return 2 * np.pi * qt.Qobj(V)

# %% [markdown]
# Second, define laser pumping and spontaneous decay and ISC. Let us define temperature independent rate first.

# %%
# Temperature independent rate
k_r    = 66.8e6   # Hz # spontaneous decay  # [Happacher 2023]
beta_x = 0.0634   # 1  # pumping parameter  # [Happacher 2023]
beta_y = 0.039    # 1  # pumping parameter  # [Happacher 2023]
k_nr1  = 90.7e6   # Hz # Excited to Singlet # [Happacher 2023]
k_nr0  = 10.5e6   # Hz # Excited to Singlet # [Happacher 2023]

# %% [markdown]
# The ISC rate from Singlet to Ground state follows Bose-Einstein statistics as follows.
# $$
# \tau (T) = \tau_0 [1 - \exp \left(\frac{-\Delta E}{k_B T}\right)]
# $$
# $$
# \frac{1}{\tau (T)} = k_{m_0} + k_{m_{\pm 1}} = k_{m_0} + k_{m_{-1}} + k_{m_1}
# $$
# The photon energy $\Delta E = 16.6$ meV and $\tau_0 = 296.53$ ns. The branching ratio is $k_{m_0} : k_{m_{-1}} : k_{m_1} = 4.36 : 1 : 1$ [Happacher 2023]

# %%
# Temperature dependent rate, ISC
def tau(T):
  tau_0   = 296.53e-9 # s    # [Happacher 2023]
  Delta_E = 16.6e-3   # eV   # [Happacher 2023]
  k_B     = 8.617e-5  # eV/K # [Happacher 2023]
  return tau_0 * (1 - np.exp(-Delta_E / (k_B * T)))

def k_m0(T):
  return 4.36/(4.36 + 1 + 1) * 1/tau(T)

def k_m1(T):
  return 1/(4.36 + 1 + 1) * 1/tau(T)

# %% [markdown]
# The photon-induced transition probability can be derived from electron-phonon interaction Hamiltonian. Let us skip the deriviation for now(Need to check any assumption or approximation in it). The result is as follows.
# $$
# k_{|X\rangle →|Y\rangle} = k_{|Y\rangle → |X\rangle} = \alpha_{ph} I(\omega_c = 60 \mathrm{meV}, T, \delta_\perp) T^5
# $$
# The phonon coupling parameter is $\alpha_{ph} = 1.4$ $\mathrm{K^5 Hz}$. The $I(\omega_c, T, \delta_\perp)$ is an integral part which corresponds to the summation part of Fermi's golden rule as follows.
# $$
# I(\omega_c, T, \delta_\perp) = \int^{x_c}_0 \mathrm{dx} x (x + x_\Delta)[x^2 + (x + x_\Delta)^2]\frac{1}{(e^x - 1)(1 - e^{-(x + x_\Delta)})}
# $$
# with $x_c = \hbar \omega_c / (k_B T)$, $\omega_c$ being the cutoff frequency in the ingegral, $x = \hbar \omega / (k_B T)$, and $x_\Delta = 2\sqrt{\delta_x^2 + \delta_y^2} / (k_B T)$.

# %%
# Temperature dependent rate, Photon-induced transition probability
alpha_ph = 1.4 # Hz/K^5

def I(omega_c, T, delta): # omega_c (eV), T (K), delta (V/m)
  h       = 4.135e-15                                                         # eV s
  print(omega_c/h)
  k_B     = 8.617e-5                                                          # eV/K
  x_c     = omega_c / (k_B * T)                                               # 1
  x_delta = h * 2 * des_perp * np.sqrt(delta[0]**2 + delta[1]**2) / (k_B * T) # 1
  x       = np.linspace(x_c/100*1, 0.9*x_c, 100)                              # 1
  dx      = x[1] - x[0]                                                       # 1
  return np.sum(dx * x * (x + x_delta) * (x**2 + (x + x_delta)**2) / (np.exp(x) - 1) / (1 - np.exp(-(x + x_delta))))

def k_xy(T, delta):
  return alpha_ph * I(60e-3, T, delta) * T**5 # hbar * omega_c = 60e-6 eV [Happacher 2023]

val = float(k_xy(100,delta))
print(val/1e9)
# Out:
# 14510278113663.844
# 561.341256994301

# %% [markdown]
# We finished to define rates so move on to the Lindbladian definition. The spontaneous decay and laser pumping are defined as follows.

# %%
# optical pumping and spontaneoud ddcay
L14 = np.sqrt(beta_y * k_r) * psi(4) * psi(1).dag()
L25 = np.sqrt(beta_y * k_r) * psi(5) * psi(2).dag()
L36 = np.sqrt(beta_y * k_r) * psi(6) * psi(3).dag()
L17 = np.sqrt(beta_x * k_r) * psi(7) * psi(1).dag()
L28 = np.sqrt(beta_x * k_r) * psi(8) * psi(2).dag()
L39 = np.sqrt(beta_x * k_r) * psi(9) * psi(3).dag()
L41 = np.sqrt(k_r) * psi(1) * psi(4).dag()
L52 = np.sqrt(k_r) * psi(2) * psi(5).dag()
L63 = np.sqrt(k_r) * psi(3) * psi(6).dag()
L71 = np.sqrt(k_r) * psi(1) * psi(7).dag()
L82 = np.sqrt(k_r) * psi(2) * psi(8).dag()
L93 = np.sqrt(k_r) * psi(3) * psi(9).dag()

# %% [markdown]
# The ISC lindbladians are defined as follows.

# %%
# ISC
L410 = np.sqrt(k_nr1) * psi(10) * psi(4).dag()
L510 = np.sqrt(k_nr0) * psi(10) * psi(5).dag()
L610 = np.sqrt(k_nr1) * psi(10) * psi(6).dag()
L710 = np.sqrt(k_nr1) * psi(10) * psi(7).dag()
L810 = np.sqrt(k_nr0) * psi(10) * psi(8).dag()
L910 = np.sqrt(k_nr1) * psi(10) * psi(9).dag()

def L101(T):
  return np.sqrt(k_m1(T)) * psi(1) * psi(10).dag()

def L102(T):
  return np.sqrt(k_m0(T)) * psi(2) * psi(10).dag()

def L103(T):
  return np.sqrt(k_m1(T)) * psi(3) * psi(10).dag()

# %% [markdown]
# The phonon-induced transitions are defined as follows.
# $$
# L_{\downarrow} = \sqrt{k_{|Y\rangle \rightarrow |X\rangle}}|Y\rangle \langle X| \otimes I_3
# $$
# $$
# L_{\uparrow} = \sqrt{k_{|X\rangle \rightarrow |Y\rangle}}|X\rangle \langle Y| \otimes I_3
# $$

# %%
def LXY(T, delta):
  return np.sqrt(k_xy(T, delta)) * (psi(7) * psi(4).dag() + psi(8) * psi(5).dag() + psi(9) * psi(6).dag())

def LYX(T, delta):
  return np.sqrt(k_xy(T, delta)) * (psi(4) * psi(7).dag() + psi(5) * psi(8).dag() + psi(6) * psi(9).dag())

# %% [markdown]
# Now we have prepared all of the Lindbladian so we can combine all of this.

# %%
def L(T, delta):
  return [L14, L25, L36, L17, L28, L39, L41, L52, L63, L71, L82, L93, L410, L510, L610, L710, L810, L910, L101(T), L102(T), L103(T), LXY(T, delta), LYX(T, delta)]

# %% [markdown]
# Let us prepare the operators for population

# %%
pop_ops = [qt.ket2dm(psi(i+1)) for i in range(10)]

# %% [markdown]
# Then we have constructed the system. We need to define the following things every calculation. We can prepare the $\rho_0$ as a constant initial state of completely mixed state in ground state.
# - Magnetic field $B$
# - Strain $\delta$
# - Temperature $T$
# - Simulation time $t_{end}$
# - Initial state $\rho_{init}$

# %%
rho_0 = 1/3 * (qt.ket2dm(psi(1)) + qt.ket2dm(psi(2)) + qt.ket2dm(psi(3)))

# %% [markdown]
# Let us see some population dynamics.

# %%
# Variables
E = [0, 0, 0] # V/m
B = [0, 0, 0] # T
delta = [10e9/des_perp/np.sqrt(2), 10e9/des_perp/np.sqrt(2), 0] # V/m
T = 3 # K
t_end = 3e-6 # s
rho_init = rho_0

# Calculation
tlist = np.linspace(0, t_end, int(t_end/1e-9)) # 1 ns step
result = qt.mesolve([H + V(E, B, delta)], rho_init, tlist, c_ops=L(T, delta), e_ops=pop_ops, options={'progress_bar': 'enhanced', 'rtol': 1e-8, 'atol': 1e-8})

# Post processing
pop = result.expect
for i in range(len(pop)):
    plt.plot(tlist, pop[i], label=str(i+1))
plt.xlabel('Time (s)')
plt.ylabel('Population')
plt.legend()
plt.show()
# Out:
# 14510278113663.844
# 14510278113663.844
#  Total run time:  58.02s

# %% [markdown]
# ##### Superoperator
# Here, we'd like to use superoperator formalism for efficient calculation.

# %% [markdown]
# The vectorlized density matrix is as follows.
# $$
# \hat{\rho} = \sum_{i, j} \rho_{i, j} |j\rangle|i\rangle
# $$

# %%
def dm2super(rho): # input:Qobj, output:numpy_array
  n = rho.shape[0]
  rho_super = qt.tensor(qt.zero_ket(n), qt.zero_ket(n))
  for i in range(n):
    for j in range(n):
      rho_super += rho[i, j] * qt.tensor(qt.basis(n, j), qt.basis(n, i))
  return rho_super.full()

# %% [markdown]
# Lindbladian superoperator is giben by as follows.
# $$
# \hat{\mathcal{L}} = i(\bar{H} \otimes I_{10} - I_{10} \otimes \bar{H}) + \sum_l \left( \bar{L_l} \otimes L_l - \frac{1}{2} I_{10} \otimes L_l^\dagger L_l - \frac{1}{2} \bar{L_l}^\dagger \bar{L_l} \otimes I_{10}\right)
# $$

# %% [markdown]
# Linbladian 方程式
# https://shyphys.org/memorandum/lindblad.html
#
# super operatorについて
# https://whyitsso.net/physics/quantum_mechanics/Lindblad_ex.html

# %%
def HL2super(H, Llist): # input:Qobj, output:numpy_array
  H = H.full()
  n = H.shape[0]
  H_super = 1j * (np.kron(np.conjugate(H), np.eye(n)) - np.kron(np.eye(n), H))
  L_super = np.zeros([n**2, n**2], dtype=np.complex128)
  for L in Llist:
    L = L.full()
    L_super += np.kron(np.conjugate(L), L) - 1/2 * np.kron(np.eye(n), np.conjugate(L).T @ L) - 1/2 * np.kron(np.conjugate(L).T @ np.conjugate(L), np.eye(n))
  return H_super + L_super

# %% [markdown]
# The time-evolution of the system in the vectorized form is given by as follows.
# $$
# \frac{d\hat{\rho}(t)}{dt} = \hat{\mathcal{L}}\hat{\rho}(t)
# $$
# $$
# \hat{\rho}(t) = e^{\mathcal{L}t}\hat{\rho}(0)
# $$
# After the calculation, the superoperator density matrix is converted back to its matrix form.

# %%
def super2dm(rho_super): # input:numpy_array, output:Qobj
  n = int(np.sqrt(rho_super.shape[0]))
  rho = np.zeros((n, n), dtype=complex)
  for i in range(n):
    for j in range(n):
      rho[i, j] = rho_super[i*n + j, 0]
  return qt.Qobj(rho)

# %% [markdown]
# Let us see the population dynamics which we saw in master eqation matrix form previously.

# %%
# Variables
E = [0, 0, 0] # V/m
B = [0, 0, 0] # T
delta = [10e9/des_perp/np.sqrt(2), 10e9/des_perp/np.sqrt(2), 0] # V/m
T = 3 # K
t_end = 3e-6 # s
rho_init = rho_0

# Convert matrix to superoperator
rho_init_super = dm2super(rho_init)
HL_super = HL2super(H + V(E, B, delta), L(T, delta))

# Calculation
tlist_super = np.linspace(0, t_end, int(t_end/1e-9) + 1) # 1 ns step
rhos_super = [sp.linalg.expm(HL_super * t) @ rho_init_super for t in tlist_super]

# Convert superoperator to matrix
rhos_super = [super2dm(rho_super) for rho_super in rhos_super]

# Post processing
pop_super = [[qt.expect(pop_op, r) for r in rhos_super] for pop_op in pop_ops]
for i in range(len(pop)):
    plt.plot(tlist_super, pop_super[i], label=str(i+1))
plt.xlabel('Time (s)')
plt.ylabel('Population')
plt.legend()
plt.show()
# Out:
# 14510278113663.844
# 14510278113663.844

# %% [markdown]
# We got a same result. From now, we can use superoperator formalism for efficient calculation.

# %% [markdown]
# ### Dependence of photoluminescence on magnetic field and temperature
#
# Here, we are going to reproduce the paper result from [Happacher 2023] as a sanity check of this program.

# %% [markdown]
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=https://drive.google.com/uc?id=114k9S3XvCQoZDFSsy02oK3GLZ4vXoFGg witdh="100">
# </div>
# <center>Figure: Figures from Happacher 2023</center>

# %% [markdown]
# #### Definition of photoluminescence

# %% [markdown]
# The photoluminescence is defined by the population in $^3 E$, multiplied by the decay rate $k_r$:
# $$
# I_{PL} = \sum_{i = 4\sim9} k_r p_i + I_{bck}.
# $$
# Here, $p_i$ is the population in state of $|i\rangle$, while $I_{bck} = 18$ kcps is the background fluorescensce.

# %%
def I_PL(pop_ss):
  eta_collection = 0.03 # collection efficiency
  I_bck = 18e3 # cps
  return eta_collection * k_r * (pop_ss[3] + pop_ss[4] + pop_ss[5] + pop_ss[6] + pop_ss[7] + pop_ss[8]) + I_bck

# %% [markdown]
# #### Photoluminscence for the low strain case

# %% [markdown]
# Calculate the I_PL for varing T and varing B

# %%
# Variables
E = [0, 0, 0] # V/m
Bz = np.linspace(0, 800e-3, 200)
theta_B = 1.05 # deg
delta_perp = 1.685e9/des_para # V/m
phi_delta = 234 # deg
delta = [delta_perp*np.sin(np.deg2rad(phi_delta)), delta_perp*np.cos(np.deg2rad(phi_delta)), 0]
T = np.linspace(1, 300, 200) # K
t_end = 3e-6 # s
rho_init = rho_0

# Calculation
rho_init_super = dm2super(rho_init)
NV_PL = []
for B_zi in B_z:
  for Ti in T:
    B = [B_zi * np.tan(np.deg2rad(theta_B)), 0, B_zi]
    HL_super = HL2super(H + V(E, B, delta), L(Ti, delta))
    rho_ss = sp.linalg.expm(HL_super * t_end) @ rho_init_super
    rho_ss = super2dm(rho_ss)
    pop_ss = [qt.expect(pop_op, rho_ss).real for pop_op in pop_ops]
    NV_PL.append(I_PL(pop_ss))

# Post processing
NV_PL = np.array([NV_PLi/1e3 for NV_PLi in NV_PL])
NV_PL = NV_PL.reshape(len(B_z), len(T))

plt.imshow(NV_PL, cmap='Blues_r', extent=[T[0], T[-1], B_z[0]*1e3, B_z[-1]*1e3], origin='lower', aspect='auto')
plt.colorbar().set_label('NV- PL (kcps)')
plt.xlabel('Temperature (K)')
plt.ylabel('Magnetic Field B_NV (mT)')
plt.show()

# %% [markdown]
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=https://drive.google.com/uc?id=11rcFZA28vv6yr323vnNl998jLC_a2xry witdh="100">
# </div>
# <center>Figure: Figures from Happacher 2023</center>

# %% [markdown]
# #### Photoluminscence for the high strain case

# %%
# Variables
E = [0, 0, 0] # V/m
Bz = np.linspace(0, 800e-3, 200)
theta_B = 1.37 # deg
delta_perp = 75e9/des_para # V/m
phi_delta = 35.3 # deg
delta = [delta_perp*np.sin(np.deg2rad(phi_delta)), delta_perp*np.cos(np.deg2rad(phi_delta)), 0]
T = np.linspace(1, 300, 200) # K
t_end = 3e-6 # s
rho_init = rho_0

# Calculation
rho_init_super = dm2super(rho_init)
NV_PL = []
for B_zi in B_z:
  for Ti in T:
    B = [B_zi * np.tan(np.deg2rad(theta_B)), 0, B_zi]
    HL_super = HL2super(H + V(E, B, delta), L(Ti, delta))
    rho_ss = sp.linalg.expm(HL_super * t_end) @ rho_init_super
    rho_ss = super2dm(rho_ss)
    pop_ss = [qt.expect(pop_op, rho_ss).real for pop_op in pop_ops]
    NV_PL.append(I_PL(pop_ss))

# Post processing
NV_PL = np.array([NV_PLi/1e3 for NV_PLi in NV_PL])
NV_PL = NV_PL.reshape(len(B_z), len(T))

plt.imshow(NV_PL, cmap='Blues_r', extent=[T[0], T[-1], B_z[0]*1e3, B_z[-1]*1e3], origin='lower', aspect='auto')
plt.colorbar().set_label('NV- PL (kcps)')
plt.xlabel('Temperature (K)')
plt.ylabel('Magnetic Field B_NV (mT)')
plt.show()

# %% [markdown]
# <div style="max-width:800px;margin-left: auto; margin-right: auto;">
# <img src=https://drive.google.com/uc?id=11tEfbtvY33Uc-N-Pk27f0xpxz72Qehwr witdh="100">
# </div>
# <center>Figure: Figures from Happacher 2023</center>

# %% [markdown]
# ### Dependence of EIT signal on magnetic field and temperature (Work in progress)

# %% [markdown]
# XXX

# %% [markdown]
# # Experimental Method and Results

# %% [markdown]
# ## Experimental setup

# %% [markdown]
# <div style="max-width:300px;margin-left: auto; margin-right: auto;">
# <img src=https://drive.google.com/uc?id=1-xiS6zZxS-GH2997McsmfOEm45vSssg9 witdh="100">
# </div>
# <center>Figure: Optics part of the NV-EIT setup</center>

# %% [markdown]
# ## Observation of the resonance using a single beam

# %% [markdown]
# ### Does the NV-EIT signal appear as a peak or a dip? -> Dip
#
# In this experiment, we detect a transmitted and a fluorescent light on top of the diamond sample. Let $I_0$ be the incident red laser power, $I_{A}$ the absorbed red laser power, $I_{T}$ the transimtted red laser power, and $I_{F}$ the red fluorescence collected by the detector. The red power into the detector $I_D$ is given by
#
# $$I_D = I_T + I_F. $$
#
# The transmitted power is $I_T = I_0 - I_A$, and the absorbed power is $I_A(\alpha) = I_0\left[1- \exp{(-\alpha z)}\right]$, where $\alpha$ is the absorption coefficient and $z$ is the path length. The fluorescnce detected is proportional to the absorbed light and the colelction efficiency: $I_F = \beta I_A$, where $\beta$ is the proportionality constant that includes the effect of collection efficiency. We assume that $I_0$, $z$, and $\beta$ stay constant, while $\alpha$ changes its value depending on the resonance. Then the detected red power is
#
# $$I_D(\alpha) = I_0 - I_A(\alpha) + \beta I_A(\alpha) = I_0  -I_0\left[1-\exp{(-\alpha z)}\right](1-\beta)$$
#
# Let $\alpha_{on}$ and $\alpha_{off}$ be the absorption coefficients when the frequency of the red laser is tuned on resonance and off resonance. Then the red signal contrast $C$ is given by
#
# $$ C = \frac{I_D(\alpha_{on})}{ I_D(\alpha_{off})} = \frac{1-\left[1-\exp{(-\alpha_{on} z)}\right](1-\beta)}{1-\left[1-\exp{(-\alpha_{off} z)}\right](1-\beta)}.$$
#
#
# Because the absorption rate increases for the resonance, we can say $\alpha_{on} \geq \alpha_{off} $. Then the following quick numerical calculation suggests that the signal is a dip.

# %%
import numpy as np

a_on = 0.12
a_off = 0.1
z = 10
beta  = 0.05
I0 = 1

Ion = I0 - I0 *(1-np.exp(-a_on *z))*(1-beta)
Ioff = I0 - I0 *(1-np.exp(-a_off *z))*(1-beta)
C = Ion / Ioff
print(C)
# Out:
# 0.8414185929291486

# %% [markdown]
# ### How wide is the absorption zero-phonon line? -? a few MHz
#
# According to Wikipedia, the zero-phonon line of the emission spectrum goes down to a few MHz at low temperature. Because the thermal broadening is suppressed, we expec that the absorption width is also on the same order.
#
# > However, cooling the NV centers with liquid nitrogen or liquid helium dramatically narrows the lines down to a width of a few MHz. At low temperature it also becomes possible to specifically address the zero-phonon line (ZPL). -Wikipdeia "NV center (https://en.wikipedia.org/wiki/Nitrogen-vacancy_center)"

# %% [markdown]
# # References

# %% [markdown]
# - [Acosta 2013] V. Acosta et al. Electromagnetically Induced Transparency in a Diamond Spin Ensemble Enables All-Optical Electromagnetic Field Sensing, Phys. Rev. Lett. (2013)  (https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.110.213605)
# - [Acosta 2012] V. M. Acosta, C. Santori, A. Faraon, Z. Huang, K.-M. C. Fu, A. Stacey, D. A. Simpson, K. Ganesan, S. Tomljenovic-Hanic, A. D. Greentree, S. Prawer, and R. G. Beausoleil, Phys. Rev. Lett. 108, 206401 (2012).1t)
# - [Bassett 2014] Bassett et al. Science, 345 (201
# - [Doherty 2013] Doherty et al. Phys Reports, 528 (2013)
# - [Goldman 2015]  M L Goldman et al. PRL, 114
# - [Goldman 2015b]] M L Goldman et al. PRB,
# - [Happacher 2023] Happacher et al. Phys Rev Lett 131 086904 (2023) (https://doi.org/10.1103/PhysRevLett.131.086904)
# - [Hemmer 2001] P. R. Hemmer et al. Raman-excited spin coherences in nitrogen-vacancy color centers in diamond. Opt. Lett. 26 (2001) 9
# - [Maze 2011] J R Maze et al. New J. Phys. 13 (201
# - [Santori 2006] Santori et al. Coherent population trapping in diamond N-V centers at zero magnetic field, Opt. Lett. 14 (2006)
# - [Santori 2006b] C. Santori, P. Tamarat, P. Neumann, J. Wrachtrup, D. Fattal, R. G. Beausoleil, J. Rabeau, P. Olivero, A. D. Greentree, S. Prawer, F. Jelezko, and P. Hemmer, Phys. Rev. Lett. 97, 247401 (2006). (https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.97.247401)
# - [Tamarat 2008]
# P. Tamarat, N. B. Manson, J. P. Harrison, R. L. McMurtrie, A. Nizovtsev, C. Santori, R. G. Beausoleil, P. Neumann, T. Gaebel, F. Jelezko, P. Hemmer, and J. Wrachtrup, New J. Phys. 10, 045004 (2008)
# - [Togan 2011]
# E. Togan, Y. Chu, A. Imamoglu, and M. D. Lukin, Nature (London) 478, 497 (2011
#
# - [Wei 1999] Changjiang Wei and Neil B. Manson Phys. Rev. A 60, 2540 (1999)
